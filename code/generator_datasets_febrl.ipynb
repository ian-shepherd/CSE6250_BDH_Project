# %% [markdown]
# ## Reproduce datasets for Scheme A
#
# Paper: "Statistical supervised meta-ensemble algorithm for data linkage"
#
# Kha Vo, Jitendra Jonnagaddala, Siaw-Teng Liaw
#
# February 2019
#
# Jounal of Biomedical Informatics

# %%
import recordlinkage as rl, pandas as pd, numpy as np
from recordlinkage.datasets import load_febrl4, load_febrl1, load_febrl2, load_febrl3
from IPython.display import clear_output

# %%
PATH_FILES =  "../data/FEBRL/"
OUTPUT_FILE_NAME = ['febrl3_rep.csv', 'febrl4_rep.csv']

# %%
## FOR DATASET febrl3

outputfile = PATH_FILES + OUTPUT_FILE_NAME[0]

df, true_links_ab = load_febrl3(return_links=True)

# WARNING: load_febrl2 and load_febrl3 does not suit this code, need further process

print("df:", len(df))
print("true_links_ab:", len(true_links_ab))
# Out:
# df: 5000
# true_links_ab: 6538

# %%
## FOR DATASET febrl4

outputfile = PATH_FILES + OUTPUT_FILE_NAME[1]

df_a, df_b, true_links_ab = load_febrl4(return_links=True) # use this for load_febrl4
df = df_a.append(df_b) # use for load_febrl4

# WARNING: load_febrl2 and load_febrl3 does not suit this code, need further process

print("df:", len(df))
print("true_links_ab:", len(true_links_ab))
# Out:
# df: 10000
# true_links_ab: 5000

# %%
df['date_of_birth']  = pd.to_datetime(df['date_of_birth'], errors = 'coerce')
df['day'] = df['date_of_birth'].dt.strftime('%d')
df['month'] = df['date_of_birth'].dt.strftime('%m')
df['year'] = df['date_of_birth'].dt.strftime('%Y')

df['postcode'] =   df['postcode'].fillna('0000')
df['postcode'] = df['postcode'].astype(int)

df['street_number'] =   df['street_number'].fillna('0')
df['street_number'] = df['street_number'].astype(int)

df = df.drop(["soc_sec_id",  "date_of_birth"], axis=1)

for col in ["surname", "given_name", "address_1", "address_2", "day", "month"]:
    df[col] = df[col].fillna('')
    df[col] = df[col].astype(str)


# df["match_id"] = range(len(df))

all_fields = df.columns.values.tolist()
#all_fields.remove('rec_id')

print("All fields:", all_fields)
df.head()
# Out:
# All fields: ['given_name', 'surname', 'street_number', 'address_1', 'address_2', 'suburb', 'postcode', 'state', 'day', 'month', 'year']
#                given_name   surname  street_number        address_1  \
# rec_id
# rec-1496-org     mitchell     green              7    wallaby place
# rec-552-dup-3      harley  mccarthy            177    pridhamstreet
# rec-988-dup-1    madeline     mason             54  hoseason street
# rec-1716-dup-1   isabelle                       23    gundulu place
# rec-1213-org       taylor  hathaway              7   yuranigh court
#
#                              address_2     suburb  postcode state day month  \
# rec_id
# rec-1496-org                    delmar  cleveland      2119    sa  09    04
# rec-552-dup-3                   milton    marsden      3165   nsw  19    04
# rec-988-dup-1   lakefront retrmnt vlge  granville      4881   nsw  28    11
# rec-1716-dup-1               currin ga   utakarra      2193    wa  19    11
# rec-1213-org            brentwood vlge        NaN      4220   nsw  07    12
#
#                 year
# rec_id
# rec-1496-org    1956
# rec-552-dup-3   1908
# rec-988-dup-1   1908
# rec-1716-dup-1  1992
# rec-1213-org    1999

# %%
df['match_id'] = [-1]*len(df)

for i in range(len(true_links_ab)):
    k0  = true_links_ab[i][0]
    k1  = true_links_ab[i][1]
    df.loc[k0, "match_id"] = i
    df.loc[k1, "match_id"] = i
    print("Processed:", i, " - " , true_links_ab[i])
# Out:
# Processed: 0  -  ('rec-552-dup-1', 'rec-552-dup-3')
# Processed: 1  -  ('rec-552-dup-0', 'rec-552-dup-3')
# Processed: 2  -  ('rec-552-dup-0', 'rec-552-dup-1')
# Processed: 3  -  ('rec-552-org', 'rec-552-dup-3')
# Processed: 4  -  ('rec-552-org', 'rec-552-dup-1')
# Processed: 5  -  ('rec-552-org', 'rec-552-dup-0')
# Processed: 6  -  ('rec-552-dup-2', 'rec-552-dup-3')
# Processed: 7  -  ('rec-552-dup-2', 'rec-552-dup-1')
# Processed: 8  -  ('rec-552-dup-2', 'rec-552-dup-0')
# Processed: 9  -  ('rec-552-dup-2', 'rec-552-org')
# Processed: 10  -  ('rec-988-org', 'rec-988-dup-1')
# Processed: 11  -  ('rec-988-dup-0', 'rec-988-dup-1')
# Processed: 12  -  ('rec-988-dup-0', 'rec-988-org')
# Processed: 13  -  ('rec-1716-dup-2', 'rec-1716-dup-1')
# Processed: 14  -  ('rec-1716-dup-0', 'rec-1716-dup-1')
# Processed: 15  -  ('rec-1716-dup-0', 'rec-1716-dup-2')
# Processed: 16  -  ('rec-1716-org', 'rec-1716-dup-1')
# Processed: 17  -  ('rec-1716-org', 'rec-1716-dup-2')
# Processed: 18  -  ('rec-1716-org', 'rec-1716-dup-0')
# Processed: 19  -  ('rec-264-org', 'rec-264-dup-0')
# Processed: 20  -  ('rec-264-dup-1', 'rec-264-dup-0')
# Processed: 21  -  ('rec-264-dup-1', 'rec-264-org')
# Processed: 22  -  ('rec-1695-dup-0', 'rec-1695-dup-3')
# Processed: 23  -  ('rec-1695-dup-2', 'rec-1695-dup-3')
# Processed: 24  -  ('rec-1695-dup-2', 'rec-1695-dup-0')
# Processed: 25  -  ('rec-1695-dup-1', 'rec-1695-dup-3')
# Processed: 26  -  ('rec-1695-dup-1', 'rec-1695-dup-0')
# Processed: 27  -  ('rec-1695-dup-1', 'rec-1695-dup-2')
# Processed: 28  -  ('rec-1695-org', 'rec-1695-dup-3')
# Processed: 29  -  ('rec-1695-org', 'rec-1695-dup-0')
# Processed: 30  -  ('rec-1695-org', 'rec-1695-dup-2')
# Processed: 31  -  ('rec-1695-org', 'rec-1695-dup-1')
# Processed: 32  -  ('rec-875-org', 'rec-875-dup-0')
# Processed: 33  -  ('rec-1778-org', 'rec-1778-dup-1')
# Processed: 34  -  ('rec-1778-dup-0', 'rec-1778-dup-1')
# Processed: 35  -  ('rec-1778-dup-0', 'rec-1778-org')
# Processed: 36  -  ('rec-1696-dup-0', 'rec-1696-dup-1')
# Processed: 37  -  ('rec-1696-org', 'rec-1696-dup-1')
# Processed: 38  -  ('rec-1696-org', 'rec-1696-dup-0')
# Processed: 39  -  ('rec-382-org', 'rec-382-dup-0')
# Processed: 40  -  ('rec-382-dup-1', 'rec-382-dup-0')
# Processed: 41  -  ('rec-382-dup-1', 'rec-382-org')
# Processed: 42  -  ('rec-442-org', 'rec-442-dup-0')
# Processed: 43  -  ('rec-1671-org', 'rec-1671-dup-0')
# Processed: 44  -  ('rec-1671-dup-3', 'rec-1671-dup-0')
# Processed: 45  -  ('rec-1671-dup-3', 'rec-1671-org')
# Processed: 46  -  ('rec-1671-dup-1', 'rec-1671-dup-0')
# Processed: 47  -  ('rec-1671-dup-1', 'rec-1671-org')
# Processed: 48  -  ('rec-1671-dup-1', 'rec-1671-dup-3')
# Processed: 49  -  ('rec-1671-dup-2', 'rec-1671-dup-0')
# Processed: 50  -  ('rec-1671-dup-2', 'rec-1671-org')
# Processed: 51  -  ('rec-1671-dup-2', 'rec-1671-dup-3')
# Processed: 52  -  ('rec-1671-dup-2', 'rec-1671-dup-1')
# Processed: 53  -  ('rec-1816-org', 'rec-1816-dup-1')
# Processed: 54  -  ('rec-1816-dup-0', 'rec-1816-dup-1')
# Processed: 55  -  ('rec-1816-dup-0', 'rec-1816-org')
# Processed: 56  -  ('rec-459-dup-0', 'rec-459-dup-4')
# Processed: 57  -  ('rec-459-dup-2', 'rec-459-dup-4')
# Processed: 58  -  ('rec-459-dup-2', 'rec-459-dup-0')
# Processed: 59  -  ('rec-459-dup-3', 'rec-459-dup-4')
# Processed: 60  -  ('rec-459-dup-3', 'rec-459-dup-0')
# Processed: 61  -  ('rec-459-dup-3', 'rec-459-dup-2')
# Processed: 62  -  ('rec-459-dup-1', 'rec-459-dup-4')
# Processed: 63  -  ('rec-459-dup-1', 'rec-459-dup-0')
# Processed: 64  -  ('rec-459-dup-1', 'rec-459-dup-2')
# Processed: 65  -  ('rec-459-dup-1', 'rec-459-dup-3')
# Processed: 66  -  ('rec-459-org', 'rec-459-dup-4')
# Processed: 67  -  ('rec-459-org', 'rec-459-dup-0')
# Processed: 68  -  ('rec-459-org', 'rec-459-dup-2')
# Processed: 69  -  ('rec-459-org', 'rec-459-dup-3')
# Processed: 70  -  ('rec-459-org', 'rec-459-dup-1')
# Processed: 71  -  ('rec-1881-dup-0', 'rec-1881-dup-1')
# Processed: 72  -  ('rec-1881-org', 'rec-1881-dup-1')
# Processed: 73  -  ('rec-1881-org', 'rec-1881-dup-0')
# Processed: 74  -  ('rec-729-dup-0', 'rec-729-org')
# Processed: 75  -  ('rec-575-dup-3', 'rec-575-dup-1')
# Processed: 76  -  ('rec-575-dup-2', 'rec-575-dup-1')
# Processed: 77  -  ('rec-575-dup-2', 'rec-575-dup-3')
# Processed: 78  -  ('rec-575-org', 'rec-575-dup-1')
# Processed: 79  -  ('rec-575-org', 'rec-575-dup-3')
# Processed: 80  -  ('rec-575-org', 'rec-575-dup-2')
# Processed: 81  -  ('rec-575-dup-0', 'rec-575-dup-1')
# Processed: 82  -  ('rec-575-dup-0', 'rec-575-dup-3')
# Processed: 83  -  ('rec-575-dup-0', 'rec-575-dup-2')
# Processed: 84  -  ('rec-575-dup-0', 'rec-575-org')
# Processed: 85  -  ('rec-292-org', 'rec-292-dup-0')
# Processed: 86  -  ('rec-834-dup-1', 'rec-834-dup-0')
# Processed: 87  -  ('rec-834-org', 'rec-834-dup-0')
# Processed: 88  -  ('rec-834-org', 'rec-834-dup-1')
# Processed: 89  -  ('rec-1943-org', 'rec-1943-dup-0')
# Processed: 90  -  ('rec-1611-dup-1', 'rec-1611-dup-0')
# Processed: 91  -  ('rec-1611-org', 'rec-1611-dup-0')
# Processed: 92  -  ('rec-1611-org', 'rec-1611-dup-1')
# Processed: 93  -  ('rec-1611-dup-2', 'rec-1611-dup-0')
# Processed: 94  -  ('rec-1611-dup-2', 'rec-1611-dup-1')
# Processed: 95  -  ('rec-1611-dup-2', 'rec-1611-org')
# Processed: 96  -  ('rec-1706-org', 'rec-1706-dup-2')
# Processed: 97  -  ('rec-1706-dup-0', 'rec-1706-dup-2')
# Processed: 98  -  ('rec-1706-dup-0', 'rec-1706-org')
# Processed: 99  -  ('rec-1706-dup-1', 'rec-1706-dup-2')
# Processed: 100  -  ('rec-1706-dup-1', 'rec-1706-org')
# Processed: 101  -  ('rec-1706-dup-1', 'rec-1706-dup-0')
# Processed: 102  -  ('rec-408-org', 'rec-408-dup-2')
# Processed: 103  -  ('rec-408-dup-0', 'rec-408-dup-2')
# Processed: 104  -  ('rec-408-dup-0', 'rec-408-org')
# Processed: 105  -  ('rec-408-dup-1', 'rec-408-dup-2')
# Processed: 106  -  ('rec-408-dup-1', 'rec-408-org')
# Processed: 107  -  ('rec-408-dup-1', 'rec-408-dup-0')
# Processed: 108  -  ('rec-1224-dup-0', 'rec-1224-org')
# Processed: 109  -  ('rec-1561-dup-1', 'rec-1561-dup-2')
# Processed: 110  -  ('rec-1561-dup-0', 'rec-1561-dup-2')
# Processed: 111  -  ('rec-1561-dup-0', 'rec-1561-dup-1')
# Processed: 112  -  ('rec-1561-dup-4', 'rec-1561-dup-2')
# Processed: 113  -  ('rec-1561-dup-4', 'rec-1561-dup-1')
# Processed: 114  -  ('rec-1561-dup-4', 'rec-1561-dup-0')
# Processed: 115  -  ('rec-1561-dup-3', 'rec-1561-dup-2')
# Processed: 116  -  ('rec-1561-dup-3', 'rec-1561-dup-1')
# Processed: 117  -  ('rec-1561-dup-3', 'rec-1561-dup-0')
# Processed: 118  -  ('rec-1561-dup-3', 'rec-1561-dup-4')
# Processed: 119  -  ('rec-1561-org', 'rec-1561-dup-2')
# Processed: 120  -  ('rec-1561-org', 'rec-1561-dup-1')
# Processed: 121  -  ('rec-1561-org', 'rec-1561-dup-0')
# Processed: 122  -  ('rec-1561-org', 'rec-1561-dup-4')
# Processed: 123  -  ('rec-1561-org', 'rec-1561-dup-3')
# Processed: 124  -  ('rec-1723-org', 'rec-1723-dup-1')
# Processed: 125  -  ('rec-1723-dup-2', 'rec-1723-dup-1')
# Processed: 126  -  ('rec-1723-dup-2', 'rec-1723-org')
# Processed: 127  -  ('rec-1723-dup-0', 'rec-1723-dup-1')
# Processed: 128  -  ('rec-1723-dup-0', 'rec-1723-org')
# Processed: 129  -  ('rec-1723-dup-0', 'rec-1723-dup-2')
# Processed: 130  -  ('rec-1781-dup-0', 'rec-1781-org')
# Processed: 131  -  ('rec-1614-dup-0', 'rec-1614-org')
# Processed: 132  -  ('rec-885-dup-1', 'rec-885-org')
# Processed: 133  -  ('rec-885-dup-2', 'rec-885-org')
# Processed: 134  -  ('rec-885-dup-2', 'rec-885-dup-1')
# Processed: 135  -  ('rec-885-dup-3', 'rec-885-org')
# Processed: 136  -  ('rec-885-dup-3', 'rec-885-dup-1')
# Processed: 137  -  ('rec-885-dup-3', 'rec-885-dup-2')
# Processed: 138  -  ('rec-885-dup-0', 'rec-885-org')
# Processed: 139  -  ('rec-885-dup-0', 'rec-885-dup-1')
# Processed: 140  -  ('rec-885-dup-0', 'rec-885-dup-2')
# Processed: 141  -  ('rec-885-dup-0', 'rec-885-dup-3')
# Processed: 142  -  ('rec-885-dup-4', 'rec-885-org')
# Processed: 143  -  ('rec-885-dup-4', 'rec-885-dup-1')
# Processed: 144  -  ('rec-885-dup-4', 'rec-885-dup-2')
# Processed: 145  -  ('rec-885-dup-4', 'rec-885-dup-3')
# Processed: 146  -  ('rec-885-dup-4', 'rec-885-dup-0')
# Processed: 147  -  ('rec-1690-dup-1', 'rec-1690-dup-2')
# Processed: 148  -  ('rec-1690-org', 'rec-1690-dup-2')
# Processed: 149  -  ('rec-1690-org', 'rec-1690-dup-1')
# Processed: 150  -  ('rec-1690-dup-0', 'rec-1690-dup-2')
# Processed: 151  -  ('rec-1690-dup-0', 'rec-1690-dup-1')
# Processed: 152  -  ('rec-1690-dup-0', 'rec-1690-org')
# Processed: 153  -  ('rec-1217-org', 'rec-1217-dup-0')
# Processed: 154  -  ('rec-1217-dup-1', 'rec-1217-dup-0')
# Processed: 155  -  ('rec-1217-dup-1', 'rec-1217-org')
# Processed: 156  -  ('rec-1217-dup-3', 'rec-1217-dup-0')
# Processed: 157  -  ('rec-1217-dup-3', 'rec-1217-org')
# Processed: 158  -  ('rec-1217-dup-3', 'rec-1217-dup-1')
# Processed: 159  -  ('rec-1217-dup-2', 'rec-1217-dup-0')
# Processed: 160  -  ('rec-1217-dup-2', 'rec-1217-org')
# Processed: 161  -  ('rec-1217-dup-2', 'rec-1217-dup-1')
# Processed: 162  -  ('rec-1217-dup-2', 'rec-1217-dup-3')
# Processed: 163  -  ('rec-1830-dup-0', 'rec-1830-dup-2')
# Processed: 164  -  ('rec-1830-org', 'rec-1830-dup-2')
# Processed: 165  -  ('rec-1830-org', 'rec-1830-dup-0')
# Processed: 166  -  ('rec-1830-dup-1', 'rec-1830-dup-2')
# Processed: 167  -  ('rec-1830-dup-1', 'rec-1830-dup-0')
# Processed: 168  -  ('rec-1830-dup-1', 'rec-1830-org')
# Processed: 169  -  ('rec-208-dup-0', 'rec-208-org')
# Processed: 170  -  ('rec-32-org', 'rec-32-dup-0')
# Processed: 171  -  ('rec-799-dup-2', 'rec-799-org')
# Processed: 172  -  ('rec-799-dup-0', 'rec-799-org')
# Processed: 173  -  ('rec-799-dup-0', 'rec-799-dup-2')
# Processed: 174  -  ('rec-799-dup-3', 'rec-799-org')
# Processed: 175  -  ('rec-799-dup-3', 'rec-799-dup-2')
# Processed: 176  -  ('rec-799-dup-3', 'rec-799-dup-0')
# Processed: 177  -  ('rec-799-dup-1', 'rec-799-org')
# Processed: 178  -  ('rec-799-dup-1', 'rec-799-dup-2')
# Processed: 179  -  ('rec-799-dup-1', 'rec-799-dup-0')
# Processed: 180  -  ('rec-799-dup-1', 'rec-799-dup-3')
# Processed: 181  -  ('rec-856-org', 'rec-856-dup-0')
# Processed: 182  -  ('rec-1128-dup-2', 'rec-1128-org')
# Processed: 183  -  ('rec-1128-dup-4', 'rec-1128-org')
# Processed: 184  -  ('rec-1128-dup-4', 'rec-1128-dup-2')
# Processed: 185  -  ('rec-1128-dup-3', 'rec-1128-org')
# Processed: 186  -  ('rec-1128-dup-3', 'rec-1128-dup-2')
# Processed: 187  -  ('rec-1128-dup-3', 'rec-1128-dup-4')
# Processed: 188  -  ('rec-1128-dup-0', 'rec-1128-org')
# Processed: 189  -  ('rec-1128-dup-0', 'rec-1128-dup-2')
# Processed: 190  -  ('rec-1128-dup-0', 'rec-1128-dup-4')
# Processed: 191  -  ('rec-1128-dup-0', 'rec-1128-dup-3')
# Processed: 192  -  ('rec-1128-dup-1', 'rec-1128-org')
# Processed: 193  -  ('rec-1128-dup-1', 'rec-1128-dup-2')
# Processed: 194  -  ('rec-1128-dup-1', 'rec-1128-dup-4')
# Processed: 195  -  ('rec-1128-dup-1', 'rec-1128-dup-3')
# Processed: 196  -  ('rec-1128-dup-1', 'rec-1128-dup-0')
# Processed: 197  -  ('rec-365-org', 'rec-365-dup-1')
# Processed: 198  -  ('rec-365-dup-0', 'rec-365-dup-1')
# Processed: 199  -  ('rec-365-dup-0', 'rec-365-org')
# Processed: 200  -  ('rec-642-dup-3', 'rec-642-dup-2')
# Processed: 201  -  ('rec-642-dup-0', 'rec-642-dup-2')
# Processed: 202  -  ('rec-642-dup-0', 'rec-642-dup-3')
# Processed: 203  -  ('rec-642-org', 'rec-642-dup-2')
# Processed: 204  -  ('rec-642-org', 'rec-642-dup-3')
# Processed: 205  -  ('rec-642-org', 'rec-642-dup-0')
# Processed: 206  -  ('rec-642-dup-4', 'rec-642-dup-2')
# Processed: 207  -  ('rec-642-dup-4', 'rec-642-dup-3')
# Processed: 208  -  ('rec-642-dup-4', 'rec-642-dup-0')
# Processed: 209  -  ('rec-642-dup-4', 'rec-642-org')
# Processed: 210  -  ('rec-642-dup-1', 'rec-642-dup-2')
# Processed: 211  -  ('rec-642-dup-1', 'rec-642-dup-3')
# Processed: 212  -  ('rec-642-dup-1', 'rec-642-dup-0')
# Processed: 213  -  ('rec-642-dup-1', 'rec-642-org')
# Processed: 214  -  ('rec-642-dup-1', 'rec-642-dup-4')
# Processed: 215  -  ('rec-854-org', 'rec-854-dup-0')
# Processed: 216  -  ('rec-421-org', 'rec-421-dup-3')
# Processed: 217  -  ('rec-421-dup-2', 'rec-421-dup-3')
# Processed: 218  -  ('rec-421-dup-2', 'rec-421-org')
# Processed: 219  -  ('rec-421-dup-4', 'rec-421-dup-3')
# Processed: 220  -  ('rec-421-dup-4', 'rec-421-org')
# Processed: 221  -  ('rec-421-dup-4', 'rec-421-dup-2')
# Processed: 222  -  ('rec-421-dup-0', 'rec-421-dup-3')
# Processed: 223  -  ('rec-421-dup-0', 'rec-421-org')
# Processed: 224  -  ('rec-421-dup-0', 'rec-421-dup-2')
# Processed: 225  -  ('rec-421-dup-0', 'rec-421-dup-4')
# Processed: 226  -  ('rec-421-dup-1', 'rec-421-dup-3')
# Processed: 227  -  ('rec-421-dup-1', 'rec-421-org')
# Processed: 228  -  ('rec-421-dup-1', 'rec-421-dup-2')
# Processed: 229  -  ('rec-421-dup-1', 'rec-421-dup-4')
# Processed: 230  -  ('rec-421-dup-1', 'rec-421-dup-0')
# Processed: 231  -  ('rec-1560-dup-1', 'rec-1560-dup-2')
# Processed: 232  -  ('rec-1560-dup-3', 'rec-1560-dup-2')
# Processed: 233  -  ('rec-1560-dup-3', 'rec-1560-dup-1')
# Processed: 234  -  ('rec-1560-dup-4', 'rec-1560-dup-2')
# Processed: 235  -  ('rec-1560-dup-4', 'rec-1560-dup-1')
# Processed: 236  -  ('rec-1560-dup-4', 'rec-1560-dup-3')
# Processed: 237  -  ('rec-1560-org', 'rec-1560-dup-2')
# Processed: 238  -  ('rec-1560-org', 'rec-1560-dup-1')
# Processed: 239  -  ('rec-1560-org', 'rec-1560-dup-3')
# Processed: 240  -  ('rec-1560-org', 'rec-1560-dup-4')
# Processed: 241  -  ('rec-1560-dup-0', 'rec-1560-dup-2')
# Processed: 242  -  ('rec-1560-dup-0', 'rec-1560-dup-1')
# Processed: 243  -  ('rec-1560-dup-0', 'rec-1560-dup-3')
# Processed: 244  -  ('rec-1560-dup-0', 'rec-1560-dup-4')
# Processed: 245  -  ('rec-1560-dup-0', 'rec-1560-org')
# Processed: 246  -  ('rec-1929-dup-0', 'rec-1929-dup-1')
# Processed: 247  -  ('rec-1929-org', 'rec-1929-dup-1')
# Processed: 248  -  ('rec-1929-org', 'rec-1929-dup-0')
# Processed: 249  -  ('rec-1992-dup-1', 'rec-1992-org')
# Processed: 250  -  ('rec-1992-dup-0', 'rec-1992-org')
# Processed: 251  -  ('rec-1992-dup-0', 'rec-1992-dup-1')
# Processed: 252  -  ('rec-1693-dup-0', 'rec-1693-dup-1')
# Processed: 253  -  ('rec-1693-org', 'rec-1693-dup-1')
# Processed: 254  -  ('rec-1693-org', 'rec-1693-dup-0')
# Processed: 255  -  ('rec-665-org', 'rec-665-dup-0')
# Processed: 256  -  ('rec-1057-dup-1', 'rec-1057-dup-2')
# Processed: 257  -  ('rec-1057-org', 'rec-1057-dup-2')
# Processed: 258  -  ('rec-1057-org', 'rec-1057-dup-1')
# Processed: 259  -  ('rec-1057-dup-0', 'rec-1057-dup-2')
# Processed: 260  -  ('rec-1057-dup-0', 'rec-1057-dup-1')
# Processed: 261  -  ('rec-1057-dup-0', 'rec-1057-org')
# Processed: 262  -  ('rec-561-dup-2', 'rec-561-dup-1')
# Processed: 263  -  ('rec-561-dup-0', 'rec-561-dup-1')
# Processed: 264  -  ('rec-561-dup-0', 'rec-561-dup-2')
# Processed: 265  -  ('rec-561-org', 'rec-561-dup-1')
# Processed: 266  -  ('rec-561-org', 'rec-561-dup-2')
# Processed: 267  -  ('rec-561-org', 'rec-561-dup-0')
# Processed: 268  -  ('rec-540-dup-3', 'rec-540-dup-2')
# Processed: 269  -  ('rec-540-dup-4', 'rec-540-dup-2')
# Processed: 270  -  ('rec-540-dup-4', 'rec-540-dup-3')
# Processed: 271  -  ('rec-540-dup-1', 'rec-540-dup-2')
# Processed: 272  -  ('rec-540-dup-1', 'rec-540-dup-3')
# Processed: 273  -  ('rec-540-dup-1', 'rec-540-dup-4')
# Processed: 274  -  ('rec-540-dup-0', 'rec-540-dup-2')
# Processed: 275  -  ('rec-540-dup-0', 'rec-540-dup-3')
# Processed: 276  -  ('rec-540-dup-0', 'rec-540-dup-4')
# Processed: 277  -  ('rec-540-dup-0', 'rec-540-dup-1')
# Processed: 278  -  ('rec-540-org', 'rec-540-dup-2')
# Processed: 279  -  ('rec-540-org', 'rec-540-dup-3')
# Processed: 280  -  ('rec-540-org', 'rec-540-dup-4')
# Processed: 281  -  ('rec-540-org', 'rec-540-dup-1')
# Processed: 282  -  ('rec-540-org', 'rec-540-dup-0')
# Processed: 283  -  ('rec-636-dup-0', 'rec-636-dup-3')
# Processed: 284  -  ('rec-636-org', 'rec-636-dup-3')
# Processed: 285  -  ('rec-636-org', 'rec-636-dup-0')
# Processed: 286  -  ('rec-636-dup-1', 'rec-636-dup-3')
# Processed: 287  -  ('rec-636-dup-1', 'rec-636-dup-0')
# Processed: 288  -  ('rec-636-dup-1', 'rec-636-org')
# Processed: 289  -  ('rec-636-dup-4', 'rec-636-dup-3')
# Processed: 290  -  ('rec-636-dup-4', 'rec-636-dup-0')
# Processed: 291  -  ('rec-636-dup-4', 'rec-636-org')
# Processed: 292  -  ('rec-636-dup-4', 'rec-636-dup-1')
# Processed: 293  -  ('rec-636-dup-2', 'rec-636-dup-3')
# Processed: 294  -  ('rec-636-dup-2', 'rec-636-dup-0')
# Processed: 295  -  ('rec-636-dup-2', 'rec-636-org')
# Processed: 296  -  ('rec-636-dup-2', 'rec-636-dup-1')
# Processed: 297  -  ('rec-636-dup-2', 'rec-636-dup-4')
# Processed: 298  -  ('rec-918-dup-0', 'rec-918-dup-1')
# Processed: 299  -  ('rec-918-dup-3', 'rec-918-dup-1')
# Processed: 300  -  ('rec-918-dup-3', 'rec-918-dup-0')
# Processed: 301  -  ('rec-918-org', 'rec-918-dup-1')
# Processed: 302  -  ('rec-918-org', 'rec-918-dup-0')
# Processed: 303  -  ('rec-918-org', 'rec-918-dup-3')
# Processed: 304  -  ('rec-918-dup-2', 'rec-918-dup-1')
# Processed: 305  -  ('rec-918-dup-2', 'rec-918-dup-0')
# Processed: 306  -  ('rec-918-dup-2', 'rec-918-dup-3')
# Processed: 307  -  ('rec-918-dup-2', 'rec-918-org')
# Processed: 308  -  ('rec-929-dup-0', 'rec-929-org')
# Processed: 309  -  ('rec-929-dup-1', 'rec-929-org')
# Processed: 310  -  ('rec-929-dup-1', 'rec-929-dup-0')
# Processed: 311  -  ('rec-1489-dup-1', 'rec-1489-org')
# Processed: 312  -  ('rec-1489-dup-2', 'rec-1489-org')
# Processed: 313  -  ('rec-1489-dup-2', 'rec-1489-dup-1')
# Processed: 314  -  ('rec-1489-dup-0', 'rec-1489-org')
# Processed: 315  -  ('rec-1489-dup-0', 'rec-1489-dup-1')
# Processed: 316  -  ('rec-1489-dup-0', 'rec-1489-dup-2')
# Processed: 317  -  ('rec-427-dup-0', 'rec-427-dup-3')
# Processed: 318  -  ('rec-427-dup-1', 'rec-427-dup-3')
# Processed: 319  -  ('rec-427-dup-1', 'rec-427-dup-0')
# Processed: 320  -  ('rec-427-org', 'rec-427-dup-3')
# Processed: 321  -  ('rec-427-org', 'rec-427-dup-0')
# Processed: 322  -  ('rec-427-org', 'rec-427-dup-1')
# Processed: 323  -  ('rec-427-dup-2', 'rec-427-dup-3')
# Processed: 324  -  ('rec-427-dup-2', 'rec-427-dup-0')
# Processed: 325  -  ('rec-427-dup-2', 'rec-427-dup-1')
# Processed: 326  -  ('rec-427-dup-2', 'rec-427-org')
# Processed: 327  -  ('rec-427-dup-4', 'rec-427-dup-3')
# Processed: 328  -  ('rec-427-dup-4', 'rec-427-dup-0')
# Processed: 329  -  ('rec-427-dup-4', 'rec-427-dup-1')
# Processed: 330  -  ('rec-427-dup-4', 'rec-427-org')
# Processed: 331  -  ('rec-427-dup-4', 'rec-427-dup-2')
# Processed: 332  -  ('rec-316-dup-2', 'rec-316-dup-0')
# Processed: 333  -  ('rec-316-dup-3', 'rec-316-dup-0')
# Processed: 334  -  ('rec-316-dup-3', 'rec-316-dup-2')
# Processed: 335  -  ('rec-316-org', 'rec-316-dup-0')
# Processed: 336  -  ('rec-316-org', 'rec-316-dup-2')
# Processed: 337  -  ('rec-316-org', 'rec-316-dup-3')
# Processed: 338  -  ('rec-316-dup-4', 'rec-316-dup-0')
# Processed: 339  -  ('rec-316-dup-4', 'rec-316-dup-2')
# Processed: 340  -  ('rec-316-dup-4', 'rec-316-dup-3')
# Processed: 341  -  ('rec-316-dup-4', 'rec-316-org')
# Processed: 342  -  ('rec-316-dup-1', 'rec-316-dup-0')
# Processed: 343  -  ('rec-316-dup-1', 'rec-316-dup-2')
# Processed: 344  -  ('rec-316-dup-1', 'rec-316-dup-3')
# Processed: 345  -  ('rec-316-dup-1', 'rec-316-org')
# Processed: 346  -  ('rec-316-dup-1', 'rec-316-dup-4')
# Processed: 347  -  ('rec-1498-dup-3', 'rec-1498-dup-0')
# Processed: 348  -  ('rec-1498-org', 'rec-1498-dup-0')
# Processed: 349  -  ('rec-1498-org', 'rec-1498-dup-3')
# Processed: 350  -  ('rec-1498-dup-1', 'rec-1498-dup-0')
# Processed: 351  -  ('rec-1498-dup-1', 'rec-1498-dup-3')
# Processed: 352  -  ('rec-1498-dup-1', 'rec-1498-org')
# Processed: 353  -  ('rec-1498-dup-4', 'rec-1498-dup-0')
# Processed: 354  -  ('rec-1498-dup-4', 'rec-1498-dup-3')
# Processed: 355  -  ('rec-1498-dup-4', 'rec-1498-org')
# Processed: 356  -  ('rec-1498-dup-4', 'rec-1498-dup-1')
# Processed: 357  -  ('rec-1498-dup-2', 'rec-1498-dup-0')
# Processed: 358  -  ('rec-1498-dup-2', 'rec-1498-dup-3')
# Processed: 359  -  ('rec-1498-dup-2', 'rec-1498-org')
# Processed: 360  -  ('rec-1498-dup-2', 'rec-1498-dup-1')
# Processed: 361  -  ('rec-1498-dup-2', 'rec-1498-dup-4')
# Processed: 362  -  ('rec-910-dup-0', 'rec-910-dup-1')
# Processed: 363  -  ('rec-910-org', 'rec-910-dup-1')
# Processed: 364  -  ('rec-910-org', 'rec-910-dup-0')
# Processed: 365  -  ('rec-1355-dup-0', 'rec-1355-org')
# Processed: 366  -  ('rec-1648-org', 'rec-1648-dup-0')
# Processed: 367  -  ('rec-1648-dup-3', 'rec-1648-dup-0')
# Processed: 368  -  ('rec-1648-dup-3', 'rec-1648-org')
# Processed: 369  -  ('rec-1648-dup-2', 'rec-1648-dup-0')
# Processed: 370  -  ('rec-1648-dup-2', 'rec-1648-org')
# Processed: 371  -  ('rec-1648-dup-2', 'rec-1648-dup-3')
# Processed: 372  -  ('rec-1648-dup-1', 'rec-1648-dup-0')
# Processed: 373  -  ('rec-1648-dup-1', 'rec-1648-org')
# Processed: 374  -  ('rec-1648-dup-1', 'rec-1648-dup-3')
# Processed: 375  -  ('rec-1648-dup-1', 'rec-1648-dup-2')
# Processed: 376  -  ('rec-658-dup-0', 'rec-658-dup-1')
# Processed: 377  -  ('rec-658-org', 'rec-658-dup-1')
# Processed: 378  -  ('rec-658-org', 'rec-658-dup-0')
# Processed: 379  -  ('rec-658-dup-2', 'rec-658-dup-1')
# Processed: 380  -  ('rec-658-dup-2', 'rec-658-dup-0')
# Processed: 381  -  ('rec-658-dup-2', 'rec-658-org')
# Processed: 382  -  ('rec-1190-org', 'rec-1190-dup-1')
# Processed: 383  -  ('rec-1190-dup-0', 'rec-1190-dup-1')
# Processed: 384  -  ('rec-1190-dup-0', 'rec-1190-org')
# Processed: 385  -  ('rec-1876-org', 'rec-1876-dup-0')
# Processed: 386  -  ('rec-305-dup-1', 'rec-305-org')
# Processed: 387  -  ('rec-305-dup-0', 'rec-305-org')
# Processed: 388  -  ('rec-305-dup-0', 'rec-305-dup-1')
# Processed: 389  -  ('rec-152-dup-0', 'rec-152-org')
# Processed: 390  -  ('rec-152-dup-2', 'rec-152-org')
# Processed: 391  -  ('rec-152-dup-2', 'rec-152-dup-0')
# Processed: 392  -  ('rec-152-dup-1', 'rec-152-org')
# Processed: 393  -  ('rec-152-dup-1', 'rec-152-dup-0')
# Processed: 394  -  ('rec-152-dup-1', 'rec-152-dup-2')
# Processed: 395  -  ('rec-1829-dup-1', 'rec-1829-dup-0')
# Processed: 396  -  ('rec-1829-org', 'rec-1829-dup-0')
# Processed: 397  -  ('rec-1829-org', 'rec-1829-dup-1')
# Processed: 398  -  ('rec-805-dup-0', 'rec-805-dup-2')
# Processed: 399  -  ('rec-805-dup-1', 'rec-805-dup-2')
# Processed: 400  -  ('rec-805-dup-1', 'rec-805-dup-0')
# Processed: 401  -  ('rec-805-org', 'rec-805-dup-2')
# Processed: 402  -  ('rec-805-org', 'rec-805-dup-0')
# Processed: 403  -  ('rec-805-org', 'rec-805-dup-1')
# Processed: 404  -  ('rec-805-dup-3', 'rec-805-dup-2')
# Processed: 405  -  ('rec-805-dup-3', 'rec-805-dup-0')
# Processed: 406  -  ('rec-805-dup-3', 'rec-805-dup-1')
# Processed: 407  -  ('rec-805-dup-3', 'rec-805-org')
# Processed: 408  -  ('rec-480-org', 'rec-480-dup-1')
# Processed: 409  -  ('rec-480-dup-0', 'rec-480-dup-1')
# Processed: 410  -  ('rec-480-dup-0', 'rec-480-org')
# Processed: 411  -  ('rec-1200-dup-1', 'rec-1200-dup-2')
# Processed: 412  -  ('rec-1200-org', 'rec-1200-dup-2')
# Processed: 413  -  ('rec-1200-org', 'rec-1200-dup-1')
# Processed: 414  -  ('rec-1200-dup-3', 'rec-1200-dup-2')
# Processed: 415  -  ('rec-1200-dup-3', 'rec-1200-dup-1')
# Processed: 416  -  ('rec-1200-dup-3', 'rec-1200-org')
# Processed: 417  -  ('rec-1200-dup-4', 'rec-1200-dup-2')
# Processed: 418  -  ('rec-1200-dup-4', 'rec-1200-dup-1')
# Processed: 419  -  ('rec-1200-dup-4', 'rec-1200-org')
# Processed: 420  -  ('rec-1200-dup-4', 'rec-1200-dup-3')
# Processed: 421  -  ('rec-1200-dup-0', 'rec-1200-dup-2')
# Processed: 422  -  ('rec-1200-dup-0', 'rec-1200-dup-1')
# Processed: 423  -  ('rec-1200-dup-0', 'rec-1200-org')
# Processed: 424  -  ('rec-1200-dup-0', 'rec-1200-dup-3')
# Processed: 425  -  ('rec-1200-dup-0', 'rec-1200-dup-4')
# Processed: 426  -  ('rec-618-dup-2', 'rec-618-org')
# Processed: 427  -  ('rec-618-dup-3', 'rec-618-org')
# Processed: 428  -  ('rec-618-dup-3', 'rec-618-dup-2')
# Processed: 429  -  ('rec-618-dup-0', 'rec-618-org')
# Processed: 430  -  ('rec-618-dup-0', 'rec-618-dup-2')
# Processed: 431  -  ('rec-618-dup-0', 'rec-618-dup-3')
# Processed: 432  -  ('rec-618-dup-1', 'rec-618-org')
# Processed: 433  -  ('rec-618-dup-1', 'rec-618-dup-2')
# Processed: 434  -  ('rec-618-dup-1', 'rec-618-dup-3')
# Processed: 435  -  ('rec-618-dup-1', 'rec-618-dup-0')
# Processed: 436  -  ('rec-1509-dup-0', 'rec-1509-org')
# Processed: 437  -  ('rec-1368-dup-0', 'rec-1368-org')
# Processed: 438  -  ('rec-879-dup-3', 'rec-879-dup-1')
# Processed: 439  -  ('rec-879-dup-2', 'rec-879-dup-1')
# Processed: 440  -  ('rec-879-dup-2', 'rec-879-dup-3')
# Processed: 441  -  ('rec-879-dup-0', 'rec-879-dup-1')
# Processed: 442  -  ('rec-879-dup-0', 'rec-879-dup-3')
# Processed: 443  -  ('rec-879-dup-0', 'rec-879-dup-2')
# Processed: 444  -  ('rec-879-org', 'rec-879-dup-1')
# Processed: 445  -  ('rec-879-org', 'rec-879-dup-3')
# Processed: 446  -  ('rec-879-org', 'rec-879-dup-2')
# Processed: 447  -  ('rec-879-org', 'rec-879-dup-0')
# Processed: 448  -  ('rec-879-dup-4', 'rec-879-dup-1')
# Processed: 449  -  ('rec-879-dup-4', 'rec-879-dup-3')
# Processed: 450  -  ('rec-879-dup-4', 'rec-879-dup-2')
# Processed: 451  -  ('rec-879-dup-4', 'rec-879-dup-0')
# Processed: 452  -  ('rec-879-dup-4', 'rec-879-org')
# Processed: 453  -  ('rec-1668-dup-3', 'rec-1668-dup-1')
# Processed: 454  -  ('rec-1668-dup-0', 'rec-1668-dup-1')
# Processed: 455  -  ('rec-1668-dup-0', 'rec-1668-dup-3')
# Processed: 456  -  ('rec-1668-org', 'rec-1668-dup-1')
# Processed: 457  -  ('rec-1668-org', 'rec-1668-dup-3')
# Processed: 458  -  ('rec-1668-org', 'rec-1668-dup-0')
# Processed: 459  -  ('rec-1668-dup-2', 'rec-1668-dup-1')
# Processed: 460  -  ('rec-1668-dup-2', 'rec-1668-dup-3')
# Processed: 461  -  ('rec-1668-dup-2', 'rec-1668-dup-0')
# Processed: 462  -  ('rec-1668-dup-2', 'rec-1668-org')
# Processed: 463  -  ('rec-794-dup-0', 'rec-794-org')
# Processed: 464  -  ('rec-1917-dup-0', 'rec-1917-dup-3')
# Processed: 465  -  ('rec-1917-org', 'rec-1917-dup-3')
# Processed: 466  -  ('rec-1917-org', 'rec-1917-dup-0')
# Processed: 467  -  ('rec-1917-dup-2', 'rec-1917-dup-3')
# Processed: 468  -  ('rec-1917-dup-2', 'rec-1917-dup-0')
# Processed: 469  -  ('rec-1917-dup-2', 'rec-1917-org')
# Processed: 470  -  ('rec-1917-dup-1', 'rec-1917-dup-3')
# Processed: 471  -  ('rec-1917-dup-1', 'rec-1917-dup-0')
# Processed: 472  -  ('rec-1917-dup-1', 'rec-1917-org')
# Processed: 473  -  ('rec-1917-dup-1', 'rec-1917-dup-2')
# Processed: 474  -  ('rec-1917-dup-4', 'rec-1917-dup-3')
# Processed: 475  -  ('rec-1917-dup-4', 'rec-1917-dup-0')
# Processed: 476  -  ('rec-1917-dup-4', 'rec-1917-org')
# Processed: 477  -  ('rec-1917-dup-4', 'rec-1917-dup-2')
# Processed: 478  -  ('rec-1917-dup-4', 'rec-1917-dup-1')
# Processed: 479  -  ('rec-1081-dup-0', 'rec-1081-dup-1')
# Processed: 480  -  ('rec-1081-org', 'rec-1081-dup-1')
# Processed: 481  -  ('rec-1081-org', 'rec-1081-dup-0')
# Processed: 482  -  ('rec-568-dup-1', 'rec-568-org')
# Processed: 483  -  ('rec-568-dup-0', 'rec-568-org')
# Processed: 484  -  ('rec-568-dup-0', 'rec-568-dup-1')
# Processed: 485  -  ('rec-368-dup-0', 'rec-368-org')
# Processed: 486  -  ('rec-666-dup-4', 'rec-666-org')
# Processed: 487  -  ('rec-666-dup-0', 'rec-666-org')
# Processed: 488  -  ('rec-666-dup-0', 'rec-666-dup-4')
# Processed: 489  -  ('rec-666-dup-2', 'rec-666-org')
# Processed: 490  -  ('rec-666-dup-2', 'rec-666-dup-4')
# Processed: 491  -  ('rec-666-dup-2', 'rec-666-dup-0')
# Processed: 492  -  ('rec-666-dup-1', 'rec-666-org')
# Processed: 493  -  ('rec-666-dup-1', 'rec-666-dup-4')
# Processed: 494  -  ('rec-666-dup-1', 'rec-666-dup-0')
# Processed: 495  -  ('rec-666-dup-1', 'rec-666-dup-2')
# Processed: 496  -  ('rec-666-dup-3', 'rec-666-org')
# Processed: 497  -  ('rec-666-dup-3', 'rec-666-dup-4')
# Processed: 498  -  ('rec-666-dup-3', 'rec-666-dup-0')
# Processed: 499  -  ('rec-666-dup-3', 'rec-666-dup-2')
# Processed: 500  -  ('rec-666-dup-3', 'rec-666-dup-1')
# Processed: 501  -  ('rec-1991-dup-4', 'rec-1991-dup-3')
# Processed: 502  -  ('rec-1991-dup-1', 'rec-1991-dup-3')
# Processed: 503  -  ('rec-1991-dup-1', 'rec-1991-dup-4')
# Processed: 504  -  ('rec-1991-dup-2', 'rec-1991-dup-3')
# Processed: 505  -  ('rec-1991-dup-2', 'rec-1991-dup-4')
# Processed: 506  -  ('rec-1991-dup-2', 'rec-1991-dup-1')
# Processed: 507  -  ('rec-1991-dup-0', 'rec-1991-dup-3')
# Processed: 508  -  ('rec-1991-dup-0', 'rec-1991-dup-4')
# Processed: 509  -  ('rec-1991-dup-0', 'rec-1991-dup-1')
# Processed: 510  -  ('rec-1991-dup-0', 'rec-1991-dup-2')
# Processed: 511  -  ('rec-1991-org', 'rec-1991-dup-3')
# Processed: 512  -  ('rec-1991-org', 'rec-1991-dup-4')
# Processed: 513  -  ('rec-1991-org', 'rec-1991-dup-1')
# Processed: 514  -  ('rec-1991-org', 'rec-1991-dup-2')
# Processed: 515  -  ('rec-1991-org', 'rec-1991-dup-0')
# Processed: 516  -  ('rec-528-dup-4', 'rec-528-dup-2')
# Processed: 517  -  ('rec-528-dup-3', 'rec-528-dup-2')
# Processed: 518  -  ('rec-528-dup-3', 'rec-528-dup-4')
# Processed: 519  -  ('rec-528-dup-0', 'rec-528-dup-2')
# Processed: 520  -  ('rec-528-dup-0', 'rec-528-dup-4')
# Processed: 521  -  ('rec-528-dup-0', 'rec-528-dup-3')
# Processed: 522  -  ('rec-528-org', 'rec-528-dup-2')
# Processed: 523  -  ('rec-528-org', 'rec-528-dup-4')
# Processed: 524  -  ('rec-528-org', 'rec-528-dup-3')
# Processed: 525  -  ('rec-528-org', 'rec-528-dup-0')
# Processed: 526  -  ('rec-528-dup-1', 'rec-528-dup-2')
# Processed: 527  -  ('rec-528-dup-1', 'rec-528-dup-4')
# Processed: 528  -  ('rec-528-dup-1', 'rec-528-dup-3')
# Processed: 529  -  ('rec-528-dup-1', 'rec-528-dup-0')
# Processed: 530  -  ('rec-528-dup-1', 'rec-528-org')
# Processed: 531  -  ('rec-1180-org', 'rec-1180-dup-0')
# Processed: 532  -  ('rec-1130-org', 'rec-1130-dup-0')
# Processed: 533  -  ('rec-1130-dup-1', 'rec-1130-dup-0')
# Processed: 534  -  ('rec-1130-dup-1', 'rec-1130-org')
# Processed: 535  -  ('rec-569-dup-1', 'rec-569-dup-2')
# Processed: 536  -  ('rec-569-dup-3', 'rec-569-dup-2')
# Processed: 537  -  ('rec-569-dup-3', 'rec-569-dup-1')
# Processed: 538  -  ('rec-569-org', 'rec-569-dup-2')
# Processed: 539  -  ('rec-569-org', 'rec-569-dup-1')
# Processed: 540  -  ('rec-569-org', 'rec-569-dup-3')
# Processed: 541  -  ('rec-569-dup-0', 'rec-569-dup-2')
# Processed: 542  -  ('rec-569-dup-0', 'rec-569-dup-1')
# Processed: 543  -  ('rec-569-dup-0', 'rec-569-dup-3')
# Processed: 544  -  ('rec-569-dup-0', 'rec-569-org')
# Processed: 545  -  ('rec-860-org', 'rec-860-dup-0')
# Processed: 546  -  ('rec-1667-dup-0', 'rec-1667-dup-1')
# Processed: 547  -  ('rec-1667-org', 'rec-1667-dup-1')
# Processed: 548  -  ('rec-1667-org', 'rec-1667-dup-0')
# Processed: 549  -  ('rec-1337-dup-3', 'rec-1337-dup-2')
# Processed: 550  -  ('rec-1337-dup-1', 'rec-1337-dup-2')
# Processed: 551  -  ('rec-1337-dup-1', 'rec-1337-dup-3')
# Processed: 552  -  ('rec-1337-dup-0', 'rec-1337-dup-2')
# Processed: 553  -  ('rec-1337-dup-0', 'rec-1337-dup-3')
# Processed: 554  -  ('rec-1337-dup-0', 'rec-1337-dup-1')
# Processed: 555  -  ('rec-1337-org', 'rec-1337-dup-2')
# Processed: 556  -  ('rec-1337-org', 'rec-1337-dup-3')
# Processed: 557  -  ('rec-1337-org', 'rec-1337-dup-1')
# Processed: 558  -  ('rec-1337-org', 'rec-1337-dup-0')
# Processed: 559  -  ('rec-1901-dup-1', 'rec-1901-dup-2')
# Processed: 560  -  ('rec-1901-dup-0', 'rec-1901-dup-2')
# Processed: 561  -  ('rec-1901-dup-0', 'rec-1901-dup-1')
# Processed: 562  -  ('rec-1901-org', 'rec-1901-dup-2')
# Processed: 563  -  ('rec-1901-org', 'rec-1901-dup-1')
# Processed: 564  -  ('rec-1901-org', 'rec-1901-dup-0')
# Processed: 565  -  ('rec-125-org', 'rec-125-dup-1')
# Processed: 566  -  ('rec-125-dup-0', 'rec-125-dup-1')
# Processed: 567  -  ('rec-125-dup-0', 'rec-125-org')
# Processed: 568  -  ('rec-125-dup-3', 'rec-125-dup-1')
# Processed: 569  -  ('rec-125-dup-3', 'rec-125-org')
# Processed: 570  -  ('rec-125-dup-3', 'rec-125-dup-0')
# Processed: 571  -  ('rec-125-dup-2', 'rec-125-dup-1')
# Processed: 572  -  ('rec-125-dup-2', 'rec-125-org')
# Processed: 573  -  ('rec-125-dup-2', 'rec-125-dup-0')
# Processed: 574  -  ('rec-125-dup-2', 'rec-125-dup-3')
# Processed: 575  -  ('rec-78-org', 'rec-78-dup-0')
# Processed: 576  -  ('rec-1953-dup-4', 'rec-1953-org')
# Processed: 577  -  ('rec-1953-dup-0', 'rec-1953-org')
# Processed: 578  -  ('rec-1953-dup-0', 'rec-1953-dup-4')
# Processed: 579  -  ('rec-1953-dup-3', 'rec-1953-org')
# Processed: 580  -  ('rec-1953-dup-3', 'rec-1953-dup-4')
# Processed: 581  -  ('rec-1953-dup-3', 'rec-1953-dup-0')
# Processed: 582  -  ('rec-1953-dup-1', 'rec-1953-org')
# Processed: 583  -  ('rec-1953-dup-1', 'rec-1953-dup-4')
# Processed: 584  -  ('rec-1953-dup-1', 'rec-1953-dup-0')
# Processed: 585  -  ('rec-1953-dup-1', 'rec-1953-dup-3')
# Processed: 586  -  ('rec-1953-dup-2', 'rec-1953-org')
# Processed: 587  -  ('rec-1953-dup-2', 'rec-1953-dup-4')
# Processed: 588  -  ('rec-1953-dup-2', 'rec-1953-dup-0')
# Processed: 589  -  ('rec-1953-dup-2', 'rec-1953-dup-3')
# Processed: 590  -  ('rec-1953-dup-2', 'rec-1953-dup-1')
# Processed: 591  -  ('rec-1981-dup-2', 'rec-1981-dup-1')
# Processed: 592  -  ('rec-1981-dup-0', 'rec-1981-dup-1')
# Processed: 593  -  ('rec-1981-dup-0', 'rec-1981-dup-2')
# Processed: 594  -  ('rec-1981-org', 'rec-1981-dup-1')
# Processed: 595  -  ('rec-1981-org', 'rec-1981-dup-2')
# Processed: 596  -  ('rec-1981-org', 'rec-1981-dup-0')
# Processed: 597  -  ('rec-479-dup-1', 'rec-479-dup-2')
# Processed: 598  -  ('rec-479-dup-0', 'rec-479-dup-2')
# Processed: 599  -  ('rec-479-dup-0', 'rec-479-dup-1')
# Processed: 600  -  ('rec-479-org', 'rec-479-dup-2')
# Processed: 601  -  ('rec-479-org', 'rec-479-dup-1')
# Processed: 602  -  ('rec-479-org', 'rec-479-dup-0')
# Processed: 603  -  ('rec-755-org', 'rec-755-dup-2')
# Processed: 604  -  ('rec-755-dup-1', 'rec-755-dup-2')
# Processed: 605  -  ('rec-755-dup-1', 'rec-755-org')
# Processed: 606  -  ('rec-755-dup-0', 'rec-755-dup-2')
# Processed: 607  -  ('rec-755-dup-0', 'rec-755-org')
# Processed: 608  -  ('rec-755-dup-0', 'rec-755-dup-1')
# Processed: 609  -  ('rec-1511-dup-0', 'rec-1511-org')
# Processed: 610  -  ('rec-1511-dup-1', 'rec-1511-org')
# Processed: 611  -  ('rec-1511-dup-1', 'rec-1511-dup-0')
# Processed: 612  -  ('rec-1387-dup-0', 'rec-1387-org')
# Processed: 613  -  ('rec-1014-dup-0', 'rec-1014-dup-2')
# Processed: 614  -  ('rec-1014-org', 'rec-1014-dup-2')
# Processed: 615  -  ('rec-1014-org', 'rec-1014-dup-0')
# Processed: 616  -  ('rec-1014-dup-1', 'rec-1014-dup-2')
# Processed: 617  -  ('rec-1014-dup-1', 'rec-1014-dup-0')
# Processed: 618  -  ('rec-1014-dup-1', 'rec-1014-org')
# Processed: 619  -  ('rec-824-org', 'rec-824-dup-0')
# Processed: 620  -  ('rec-824-dup-3', 'rec-824-dup-0')
# Processed: 621  -  ('rec-824-dup-3', 'rec-824-org')
# Processed: 622  -  ('rec-824-dup-1', 'rec-824-dup-0')
# Processed: 623  -  ('rec-824-dup-1', 'rec-824-org')
# Processed: 624  -  ('rec-824-dup-1', 'rec-824-dup-3')
# Processed: 625  -  ('rec-824-dup-2', 'rec-824-dup-0')
# Processed: 626  -  ('rec-824-dup-2', 'rec-824-org')
# Processed: 627  -  ('rec-824-dup-2', 'rec-824-dup-3')
# Processed: 628  -  ('rec-824-dup-2', 'rec-824-dup-1')
# Processed: 629  -  ('rec-1857-dup-1', 'rec-1857-dup-4')
# Processed: 630  -  ('rec-1857-dup-2', 'rec-1857-dup-4')
# Processed: 631  -  ('rec-1857-dup-2', 'rec-1857-dup-1')
# Processed: 632  -  ('rec-1857-dup-3', 'rec-1857-dup-4')
# Processed: 633  -  ('rec-1857-dup-3', 'rec-1857-dup-1')
# Processed: 634  -  ('rec-1857-dup-3', 'rec-1857-dup-2')
# Processed: 635  -  ('rec-1857-org', 'rec-1857-dup-4')
# Processed: 636  -  ('rec-1857-org', 'rec-1857-dup-1')
# Processed: 637  -  ('rec-1857-org', 'rec-1857-dup-2')
# Processed: 638  -  ('rec-1857-org', 'rec-1857-dup-3')
# Processed: 639  -  ('rec-1857-dup-0', 'rec-1857-dup-4')
# Processed: 640  -  ('rec-1857-dup-0', 'rec-1857-dup-1')
# Processed: 641  -  ('rec-1857-dup-0', 'rec-1857-dup-2')
# Processed: 642  -  ('rec-1857-dup-0', 'rec-1857-dup-3')
# Processed: 643  -  ('rec-1857-dup-0', 'rec-1857-org')
# Processed: 644  -  ('rec-1590-dup-0', 'rec-1590-org')
# Processed: 645  -  ('rec-1996-dup-2', 'rec-1996-org')
# Processed: 646  -  ('rec-1996-dup-4', 'rec-1996-org')
# Processed: 647  -  ('rec-1996-dup-4', 'rec-1996-dup-2')
# Processed: 648  -  ('rec-1996-dup-1', 'rec-1996-org')
# Processed: 649  -  ('rec-1996-dup-1', 'rec-1996-dup-2')
# Processed: 650  -  ('rec-1996-dup-1', 'rec-1996-dup-4')
# Processed: 651  -  ('rec-1996-dup-0', 'rec-1996-org')
# Processed: 652  -  ('rec-1996-dup-0', 'rec-1996-dup-2')
# Processed: 653  -  ('rec-1996-dup-0', 'rec-1996-dup-4')
# Processed: 654  -  ('rec-1996-dup-0', 'rec-1996-dup-1')
# Processed: 655  -  ('rec-1996-dup-3', 'rec-1996-org')
# Processed: 656  -  ('rec-1996-dup-3', 'rec-1996-dup-2')
# Processed: 657  -  ('rec-1996-dup-3', 'rec-1996-dup-4')
# Processed: 658  -  ('rec-1996-dup-3', 'rec-1996-dup-1')
# Processed: 659  -  ('rec-1996-dup-3', 'rec-1996-dup-0')
# Processed: 660  -  ('rec-1540-dup-3', 'rec-1540-dup-2')
# Processed: 661  -  ('rec-1540-org', 'rec-1540-dup-2')
# Processed: 662  -  ('rec-1540-org', 'rec-1540-dup-3')
# Processed: 663  -  ('rec-1540-dup-1', 'rec-1540-dup-2')
# Processed: 664  -  ('rec-1540-dup-1', 'rec-1540-dup-3')
# Processed: 665  -  ('rec-1540-dup-1', 'rec-1540-org')
# Processed: 666  -  ('rec-1540-dup-0', 'rec-1540-dup-2')
# Processed: 667  -  ('rec-1540-dup-0', 'rec-1540-dup-3')
# Processed: 668  -  ('rec-1540-dup-0', 'rec-1540-org')
# Processed: 669  -  ('rec-1540-dup-0', 'rec-1540-dup-1')
# Processed: 670  -  ('rec-935-dup-1', 'rec-935-dup-0')
# Processed: 671  -  ('rec-935-dup-4', 'rec-935-dup-0')
# Processed: 672  -  ('rec-935-dup-4', 'rec-935-dup-1')
# Processed: 673  -  ('rec-935-dup-2', 'rec-935-dup-0')
# Processed: 674  -  ('rec-935-dup-2', 'rec-935-dup-1')
# Processed: 675  -  ('rec-935-dup-2', 'rec-935-dup-4')
# Processed: 676  -  ('rec-935-dup-3', 'rec-935-dup-0')
# Processed: 677  -  ('rec-935-dup-3', 'rec-935-dup-1')
# Processed: 678  -  ('rec-935-dup-3', 'rec-935-dup-4')
# Processed: 679  -  ('rec-935-dup-3', 'rec-935-dup-2')
# Processed: 680  -  ('rec-935-org', 'rec-935-dup-0')
# Processed: 681  -  ('rec-935-org', 'rec-935-dup-1')
# Processed: 682  -  ('rec-935-org', 'rec-935-dup-4')
# Processed: 683  -  ('rec-935-org', 'rec-935-dup-2')
# Processed: 684  -  ('rec-935-org', 'rec-935-dup-3')
# Processed: 685  -  ('rec-1183-dup-0', 'rec-1183-org')
# Processed: 686  -  ('rec-1062-dup-3', 'rec-1062-dup-1')
# Processed: 687  -  ('rec-1062-org', 'rec-1062-dup-1')
# Processed: 688  -  ('rec-1062-org', 'rec-1062-dup-3')
# Processed: 689  -  ('rec-1062-dup-0', 'rec-1062-dup-1')
# Processed: 690  -  ('rec-1062-dup-0', 'rec-1062-dup-3')
# Processed: 691  -  ('rec-1062-dup-0', 'rec-1062-org')
# Processed: 692  -  ('rec-1062-dup-2', 'rec-1062-dup-1')
# Processed: 693  -  ('rec-1062-dup-2', 'rec-1062-dup-3')
# Processed: 694  -  ('rec-1062-dup-2', 'rec-1062-org')
# Processed: 695  -  ('rec-1062-dup-2', 'rec-1062-dup-0')
# Processed: 696  -  ('rec-256-dup-2', 'rec-256-dup-0')
# Processed: 697  -  ('rec-256-dup-3', 'rec-256-dup-0')
# Processed: 698  -  ('rec-256-dup-3', 'rec-256-dup-2')
# Processed: 699  -  ('rec-256-dup-4', 'rec-256-dup-0')
# Processed: 700  -  ('rec-256-dup-4', 'rec-256-dup-2')
# Processed: 701  -  ('rec-256-dup-4', 'rec-256-dup-3')
# Processed: 702  -  ('rec-256-dup-1', 'rec-256-dup-0')
# Processed: 703  -  ('rec-256-dup-1', 'rec-256-dup-2')
# Processed: 704  -  ('rec-256-dup-1', 'rec-256-dup-3')
# Processed: 705  -  ('rec-256-dup-1', 'rec-256-dup-4')
# Processed: 706  -  ('rec-256-org', 'rec-256-dup-0')
# Processed: 707  -  ('rec-256-org', 'rec-256-dup-2')
# Processed: 708  -  ('rec-256-org', 'rec-256-dup-3')
# Processed: 709  -  ('rec-256-org', 'rec-256-dup-4')
# Processed: 710  -  ('rec-256-org', 'rec-256-dup-1')
# Processed: 711  -  ('rec-1895-dup-0', 'rec-1895-dup-3')
# Processed: 712  -  ('rec-1895-org', 'rec-1895-dup-3')
# Processed: 713  -  ('rec-1895-org', 'rec-1895-dup-0')
# Processed: 714  -  ('rec-1895-dup-1', 'rec-1895-dup-3')
# Processed: 715  -  ('rec-1895-dup-1', 'rec-1895-dup-0')
# Processed: 716  -  ('rec-1895-dup-1', 'rec-1895-org')
# Processed: 717  -  ('rec-1895-dup-2', 'rec-1895-dup-3')
# Processed: 718  -  ('rec-1895-dup-2', 'rec-1895-dup-0')
# Processed: 719  -  ('rec-1895-dup-2', 'rec-1895-org')
# Processed: 720  -  ('rec-1895-dup-2', 'rec-1895-dup-1')
# Processed: 721  -  ('rec-401-dup-0', 'rec-401-dup-4')
# Processed: 722  -  ('rec-401-dup-3', 'rec-401-dup-4')
# Processed: 723  -  ('rec-401-dup-3', 'rec-401-dup-0')
# Processed: 724  -  ('rec-401-dup-2', 'rec-401-dup-4')
# Processed: 725  -  ('rec-401-dup-2', 'rec-401-dup-0')
# Processed: 726  -  ('rec-401-dup-2', 'rec-401-dup-3')
# Processed: 727  -  ('rec-401-dup-1', 'rec-401-dup-4')
# Processed: 728  -  ('rec-401-dup-1', 'rec-401-dup-0')
# Processed: 729  -  ('rec-401-dup-1', 'rec-401-dup-3')
# Processed: 730  -  ('rec-401-dup-1', 'rec-401-dup-2')
# Processed: 731  -  ('rec-401-org', 'rec-401-dup-4')
# Processed: 732  -  ('rec-401-org', 'rec-401-dup-0')
# Processed: 733  -  ('rec-401-org', 'rec-401-dup-3')
# Processed: 734  -  ('rec-401-org', 'rec-401-dup-2')
# Processed: 735  -  ('rec-401-org', 'rec-401-dup-1')
# Processed: 736  -  ('rec-571-dup-1', 'rec-571-org')
# Processed: 737  -  ('rec-571-dup-0', 'rec-571-org')
# Processed: 738  -  ('rec-571-dup-0', 'rec-571-dup-1')
# Processed: 739  -  ('rec-133-dup-0', 'rec-133-dup-4')
# Processed: 740  -  ('rec-133-dup-2', 'rec-133-dup-4')
# Processed: 741  -  ('rec-133-dup-2', 'rec-133-dup-0')
# Processed: 742  -  ('rec-133-dup-3', 'rec-133-dup-4')
# Processed: 743  -  ('rec-133-dup-3', 'rec-133-dup-0')
# Processed: 744  -  ('rec-133-dup-3', 'rec-133-dup-2')
# Processed: 745  -  ('rec-133-org', 'rec-133-dup-4')
# Processed: 746  -  ('rec-133-org', 'rec-133-dup-0')
# Processed: 747  -  ('rec-133-org', 'rec-133-dup-2')
# Processed: 748  -  ('rec-133-org', 'rec-133-dup-3')
# Processed: 749  -  ('rec-133-dup-1', 'rec-133-dup-4')
# Processed: 750  -  ('rec-133-dup-1', 'rec-133-dup-0')
# Processed: 751  -  ('rec-133-dup-1', 'rec-133-dup-2')
# Processed: 752  -  ('rec-133-dup-1', 'rec-133-dup-3')
# Processed: 753  -  ('rec-133-dup-1', 'rec-133-org')
# Processed: 754  -  ('rec-1534-org', 'rec-1534-dup-4')
# Processed: 755  -  ('rec-1534-dup-3', 'rec-1534-dup-4')
# Processed: 756  -  ('rec-1534-dup-3', 'rec-1534-org')
# Processed: 757  -  ('rec-1534-dup-1', 'rec-1534-dup-4')
# Processed: 758  -  ('rec-1534-dup-1', 'rec-1534-org')
# Processed: 759  -  ('rec-1534-dup-1', 'rec-1534-dup-3')
# Processed: 760  -  ('rec-1534-dup-0', 'rec-1534-dup-4')
# Processed: 761  -  ('rec-1534-dup-0', 'rec-1534-org')
# Processed: 762  -  ('rec-1534-dup-0', 'rec-1534-dup-3')
# Processed: 763  -  ('rec-1534-dup-0', 'rec-1534-dup-1')
# Processed: 764  -  ('rec-1534-dup-2', 'rec-1534-dup-4')
# Processed: 765  -  ('rec-1534-dup-2', 'rec-1534-org')
# Processed: 766  -  ('rec-1534-dup-2', 'rec-1534-dup-3')
# Processed: 767  -  ('rec-1534-dup-2', 'rec-1534-dup-1')
# Processed: 768  -  ('rec-1534-dup-2', 'rec-1534-dup-0')
# Processed: 769  -  ('rec-1566-dup-2', 'rec-1566-dup-3')
# Processed: 770  -  ('rec-1566-org', 'rec-1566-dup-3')
# Processed: 771  -  ('rec-1566-org', 'rec-1566-dup-2')
# Processed: 772  -  ('rec-1566-dup-0', 'rec-1566-dup-3')
# Processed: 773  -  ('rec-1566-dup-0', 'rec-1566-dup-2')
# Processed: 774  -  ('rec-1566-dup-0', 'rec-1566-org')
# Processed: 775  -  ('rec-1566-dup-1', 'rec-1566-dup-3')
# Processed: 776  -  ('rec-1566-dup-1', 'rec-1566-dup-2')
# Processed: 777  -  ('rec-1566-dup-1', 'rec-1566-org')
# Processed: 778  -  ('rec-1566-dup-1', 'rec-1566-dup-0')
# Processed: 779  -  ('rec-165-dup-0', 'rec-165-org')
# Processed: 780  -  ('rec-165-dup-1', 'rec-165-org')
# Processed: 781  -  ('rec-165-dup-1', 'rec-165-dup-0')
# Processed: 782  -  ('rec-1610-dup-1', 'rec-1610-org')
# Processed: 783  -  ('rec-1610-dup-0', 'rec-1610-org')
# Processed: 784  -  ('rec-1610-dup-0', 'rec-1610-dup-1')
# Processed: 785  -  ('rec-1610-dup-2', 'rec-1610-org')
# Processed: 786  -  ('rec-1610-dup-2', 'rec-1610-dup-1')
# Processed: 787  -  ('rec-1610-dup-2', 'rec-1610-dup-0')
# Processed: 788  -  ('rec-1610-dup-3', 'rec-1610-org')
# Processed: 789  -  ('rec-1610-dup-3', 'rec-1610-dup-1')
# Processed: 790  -  ('rec-1610-dup-3', 'rec-1610-dup-0')
# Processed: 791  -  ('rec-1610-dup-3', 'rec-1610-dup-2')
# Processed: 792  -  ('rec-1446-dup-0', 'rec-1446-org')
# Processed: 793  -  ('rec-118-dup-1', 'rec-118-org')
# Processed: 794  -  ('rec-118-dup-0', 'rec-118-org')
# Processed: 795  -  ('rec-118-dup-0', 'rec-118-dup-1')
# Processed: 796  -  ('rec-486-org', 'rec-486-dup-0')
# Processed: 797  -  ('rec-1388-org', 'rec-1388-dup-0')
# Processed: 798  -  ('rec-1388-dup-1', 'rec-1388-dup-0')
# Processed: 799  -  ('rec-1388-dup-1', 'rec-1388-org')
# Processed: 800  -  ('rec-703-dup-2', 'rec-703-org')
# Processed: 801  -  ('rec-703-dup-0', 'rec-703-org')
# Processed: 802  -  ('rec-703-dup-0', 'rec-703-dup-2')
# Processed: 803  -  ('rec-703-dup-1', 'rec-703-org')
# Processed: 804  -  ('rec-703-dup-1', 'rec-703-dup-2')
# Processed: 805  -  ('rec-703-dup-1', 'rec-703-dup-0')
# Processed: 806  -  ('rec-732-dup-2', 'rec-732-dup-1')
# Processed: 807  -  ('rec-732-dup-0', 'rec-732-dup-1')
# Processed: 808  -  ('rec-732-dup-0', 'rec-732-dup-2')
# Processed: 809  -  ('rec-732-dup-3', 'rec-732-dup-1')
# Processed: 810  -  ('rec-732-dup-3', 'rec-732-dup-2')
# Processed: 811  -  ('rec-732-dup-3', 'rec-732-dup-0')
# Processed: 812  -  ('rec-732-org', 'rec-732-dup-1')
# Processed: 813  -  ('rec-732-org', 'rec-732-dup-2')
# Processed: 814  -  ('rec-732-org', 'rec-732-dup-0')
# Processed: 815  -  ('rec-732-org', 'rec-732-dup-3')
# Processed: 816  -  ('rec-286-dup-4', 'rec-286-dup-2')
# Processed: 817  -  ('rec-286-dup-1', 'rec-286-dup-2')
# Processed: 818  -  ('rec-286-dup-1', 'rec-286-dup-4')
# Processed: 819  -  ('rec-286-dup-0', 'rec-286-dup-2')
# Processed: 820  -  ('rec-286-dup-0', 'rec-286-dup-4')
# Processed: 821  -  ('rec-286-dup-0', 'rec-286-dup-1')
# Processed: 822  -  ('rec-286-org', 'rec-286-dup-2')
# Processed: 823  -  ('rec-286-org', 'rec-286-dup-4')
# Processed: 824  -  ('rec-286-org', 'rec-286-dup-1')
# Processed: 825  -  ('rec-286-org', 'rec-286-dup-0')
# Processed: 826  -  ('rec-286-dup-3', 'rec-286-dup-2')
# Processed: 827  -  ('rec-286-dup-3', 'rec-286-dup-4')
# Processed: 828  -  ('rec-286-dup-3', 'rec-286-dup-1')
# Processed: 829  -  ('rec-286-dup-3', 'rec-286-dup-0')
# Processed: 830  -  ('rec-286-dup-3', 'rec-286-org')
# Processed: 831  -  ('rec-13-dup-0', 'rec-13-org')
# Processed: 832  -  ('rec-299-dup-2', 'rec-299-org')
# Processed: 833  -  ('rec-299-dup-0', 'rec-299-org')
# Processed: 834  -  ('rec-299-dup-0', 'rec-299-dup-2')
# Processed: 835  -  ('rec-299-dup-1', 'rec-299-org')
# Processed: 836  -  ('rec-299-dup-1', 'rec-299-dup-2')
# Processed: 837  -  ('rec-299-dup-1', 'rec-299-dup-0')
# Processed: 838  -  ('rec-1442-dup-1', 'rec-1442-org')
# Processed: 839  -  ('rec-1442-dup-0', 'rec-1442-org')
# Processed: 840  -  ('rec-1442-dup-0', 'rec-1442-dup-1')
# Processed: 841  -  ('rec-779-dup-3', 'rec-779-dup-2')
# Processed: 842  -  ('rec-779-dup-0', 'rec-779-dup-2')
# Processed: 843  -  ('rec-779-dup-0', 'rec-779-dup-3')
# Processed: 844  -  ('rec-779-dup-1', 'rec-779-dup-2')
# Processed: 845  -  ('rec-779-dup-1', 'rec-779-dup-3')
# Processed: 846  -  ('rec-779-dup-1', 'rec-779-dup-0')
# Processed: 847  -  ('rec-779-org', 'rec-779-dup-2')
# Processed: 848  -  ('rec-779-org', 'rec-779-dup-3')
# Processed: 849  -  ('rec-779-org', 'rec-779-dup-0')
# Processed: 850  -  ('rec-779-org', 'rec-779-dup-1')
# Processed: 851  -  ('rec-375-dup-1', 'rec-375-dup-2')
# Processed: 852  -  ('rec-375-dup-0', 'rec-375-dup-2')
# Processed: 853  -  ('rec-375-dup-0', 'rec-375-dup-1')
# Processed: 854  -  ('rec-375-dup-3', 'rec-375-dup-2')
# Processed: 855  -  ('rec-375-dup-3', 'rec-375-dup-1')
# Processed: 856  -  ('rec-375-dup-3', 'rec-375-dup-0')
# Processed: 857  -  ('rec-375-org', 'rec-375-dup-2')
# Processed: 858  -  ('rec-375-org', 'rec-375-dup-1')
# Processed: 859  -  ('rec-375-org', 'rec-375-dup-0')
# Processed: 860  -  ('rec-375-org', 'rec-375-dup-3')
# Processed: 861  -  ('rec-1883-dup-3', 'rec-1883-dup-1')
# Processed: 862  -  ('rec-1883-dup-0', 'rec-1883-dup-1')
# Processed: 863  -  ('rec-1883-dup-0', 'rec-1883-dup-3')
# Processed: 864  -  ('rec-1883-dup-2', 'rec-1883-dup-1')
# Processed: 865  -  ('rec-1883-dup-2', 'rec-1883-dup-3')
# Processed: 866  -  ('rec-1883-dup-2', 'rec-1883-dup-0')
# Processed: 867  -  ('rec-1883-dup-4', 'rec-1883-dup-1')
# Processed: 868  -  ('rec-1883-dup-4', 'rec-1883-dup-3')
# Processed: 869  -  ('rec-1883-dup-4', 'rec-1883-dup-0')
# Processed: 870  -  ('rec-1883-dup-4', 'rec-1883-dup-2')
# Processed: 871  -  ('rec-1883-org', 'rec-1883-dup-1')
# Processed: 872  -  ('rec-1883-org', 'rec-1883-dup-3')
# Processed: 873  -  ('rec-1883-org', 'rec-1883-dup-0')
# Processed: 874  -  ('rec-1883-org', 'rec-1883-dup-2')
# Processed: 875  -  ('rec-1883-org', 'rec-1883-dup-4')
# Processed: 876  -  ('rec-438-dup-0', 'rec-438-org')
# Processed: 877  -  ('rec-438-dup-1', 'rec-438-org')
# Processed: 878  -  ('rec-438-dup-1', 'rec-438-dup-0')
# Processed: 879  -  ('rec-1232-dup-2', 'rec-1232-dup-1')
# Processed: 880  -  ('rec-1232-org', 'rec-1232-dup-1')
# Processed: 881  -  ('rec-1232-org', 'rec-1232-dup-2')
# Processed: 882  -  ('rec-1232-dup-0', 'rec-1232-dup-1')
# Processed: 883  -  ('rec-1232-dup-0', 'rec-1232-dup-2')
# Processed: 884  -  ('rec-1232-dup-0', 'rec-1232-org')
# Processed: 885  -  ('rec-1232-dup-4', 'rec-1232-dup-1')
# Processed: 886  -  ('rec-1232-dup-4', 'rec-1232-dup-2')
# Processed: 887  -  ('rec-1232-dup-4', 'rec-1232-org')
# Processed: 888  -  ('rec-1232-dup-4', 'rec-1232-dup-0')
# ...
# Processed: 6245  -  ('rec-453-dup-0', 'rec-453-org')
# Processed: 6246  -  ('rec-1597-org', 'rec-1597-dup-0')
# Processed: 6247  -  ('rec-1332-dup-0', 'rec-1332-dup-1')
# Processed: 6248  -  ('rec-1332-org', 'rec-1332-dup-1')
# Processed: 6249  -  ('rec-1332-org', 'rec-1332-dup-0')
# Processed: 6250  -  ('rec-178-dup-1', 'rec-178-dup-3')
# Processed: 6251  -  ('rec-178-org', 'rec-178-dup-3')
# Processed: 6252  -  ('rec-178-org', 'rec-178-dup-1')
# Processed: 6253  -  ('rec-178-dup-2', 'rec-178-dup-3')
# Processed: 6254  -  ('rec-178-dup-2', 'rec-178-dup-1')
# Processed: 6255  -  ('rec-178-dup-2', 'rec-178-org')
# Processed: 6256  -  ('rec-178-dup-0', 'rec-178-dup-3')
# Processed: 6257  -  ('rec-178-dup-0', 'rec-178-dup-1')
# Processed: 6258  -  ('rec-178-dup-0', 'rec-178-org')
# Processed: 6259  -  ('rec-178-dup-0', 'rec-178-dup-2')
# Processed: 6260  -  ('rec-574-org', 'rec-574-dup-0')
# Processed: 6261  -  ('rec-1034-org', 'rec-1034-dup-1')
# Processed: 6262  -  ('rec-1034-dup-2', 'rec-1034-dup-1')
# Processed: 6263  -  ('rec-1034-dup-2', 'rec-1034-org')
# Processed: 6264  -  ('rec-1034-dup-0', 'rec-1034-dup-1')
# Processed: 6265  -  ('rec-1034-dup-0', 'rec-1034-org')
# Processed: 6266  -  ('rec-1034-dup-0', 'rec-1034-dup-2')
# Processed: 6267  -  ('rec-641-dup-3', 'rec-641-dup-0')
# Processed: 6268  -  ('rec-641-org', 'rec-641-dup-0')
# Processed: 6269  -  ('rec-641-org', 'rec-641-dup-3')
# Processed: 6270  -  ('rec-641-dup-2', 'rec-641-dup-0')
# Processed: 6271  -  ('rec-641-dup-2', 'rec-641-dup-3')
# Processed: 6272  -  ('rec-641-dup-2', 'rec-641-org')
# Processed: 6273  -  ('rec-641-dup-1', 'rec-641-dup-0')
# Processed: 6274  -  ('rec-641-dup-1', 'rec-641-dup-3')
# Processed: 6275  -  ('rec-641-dup-1', 'rec-641-org')
# Processed: 6276  -  ('rec-641-dup-1', 'rec-641-dup-2')
# Processed: 6277  -  ('rec-1021-dup-0', 'rec-1021-org')
# Processed: 6278  -  ('rec-1000-org', 'rec-1000-dup-0')
# Processed: 6279  -  ('rec-1000-dup-1', 'rec-1000-dup-0')
# Processed: 6280  -  ('rec-1000-dup-1', 'rec-1000-org')
# Processed: 6281  -  ('rec-392-org', 'rec-392-dup-0')
# Processed: 6282  -  ('rec-951-org', 'rec-951-dup-0')
# Processed: 6283  -  ('rec-164-dup-0', 'rec-164-org')
# Processed: 6284  -  ('rec-1594-dup-0', 'rec-1594-org')
# Processed: 6285  -  ('rec-748-org', 'rec-748-dup-0')
# Processed: 6286  -  ('rec-1201-org', 'rec-1201-dup-0')
# Processed: 6287  -  ('rec-1252-org', 'rec-1252-dup-0')
# Processed: 6288  -  ('rec-1252-dup-1', 'rec-1252-dup-0')
# Processed: 6289  -  ('rec-1252-dup-1', 'rec-1252-org')
# Processed: 6290  -  ('rec-456-dup-0', 'rec-456-dup-2')
# Processed: 6291  -  ('rec-456-org', 'rec-456-dup-2')
# Processed: 6292  -  ('rec-456-org', 'rec-456-dup-0')
# Processed: 6293  -  ('rec-456-dup-1', 'rec-456-dup-2')
# Processed: 6294  -  ('rec-456-dup-1', 'rec-456-dup-0')
# Processed: 6295  -  ('rec-456-dup-1', 'rec-456-org')
# Processed: 6296  -  ('rec-782-org', 'rec-782-dup-0')
# Processed: 6297  -  ('rec-782-dup-1', 'rec-782-dup-0')
# Processed: 6298  -  ('rec-782-dup-1', 'rec-782-org')
# Processed: 6299  -  ('rec-262-dup-1', 'rec-262-dup-2')
# Processed: 6300  -  ('rec-262-dup-3', 'rec-262-dup-2')
# Processed: 6301  -  ('rec-262-dup-3', 'rec-262-dup-1')
# Processed: 6302  -  ('rec-262-dup-0', 'rec-262-dup-2')
# Processed: 6303  -  ('rec-262-dup-0', 'rec-262-dup-1')
# Processed: 6304  -  ('rec-262-dup-0', 'rec-262-dup-3')
# Processed: 6305  -  ('rec-262-org', 'rec-262-dup-2')
# Processed: 6306  -  ('rec-262-org', 'rec-262-dup-1')
# Processed: 6307  -  ('rec-262-org', 'rec-262-dup-3')
# Processed: 6308  -  ('rec-262-org', 'rec-262-dup-0')
# Processed: 6309  -  ('rec-1472-dup-0', 'rec-1472-org')
# Processed: 6310  -  ('rec-38-org', 'rec-38-dup-1')
# Processed: 6311  -  ('rec-38-dup-0', 'rec-38-dup-1')
# Processed: 6312  -  ('rec-38-dup-0', 'rec-38-org')
# Processed: 6313  -  ('rec-976-dup-2', 'rec-976-dup-3')
# Processed: 6314  -  ('rec-976-dup-1', 'rec-976-dup-3')
# Processed: 6315  -  ('rec-976-dup-1', 'rec-976-dup-2')
# Processed: 6316  -  ('rec-976-dup-4', 'rec-976-dup-3')
# Processed: 6317  -  ('rec-976-dup-4', 'rec-976-dup-2')
# Processed: 6318  -  ('rec-976-dup-4', 'rec-976-dup-1')
# Processed: 6319  -  ('rec-976-org', 'rec-976-dup-3')
# Processed: 6320  -  ('rec-976-org', 'rec-976-dup-2')
# Processed: 6321  -  ('rec-976-org', 'rec-976-dup-1')
# Processed: 6322  -  ('rec-976-org', 'rec-976-dup-4')
# Processed: 6323  -  ('rec-976-dup-0', 'rec-976-dup-3')
# Processed: 6324  -  ('rec-976-dup-0', 'rec-976-dup-2')
# Processed: 6325  -  ('rec-976-dup-0', 'rec-976-dup-1')
# Processed: 6326  -  ('rec-976-dup-0', 'rec-976-dup-4')
# Processed: 6327  -  ('rec-976-dup-0', 'rec-976-org')
# Processed: 6328  -  ('rec-1248-dup-2', 'rec-1248-org')
# Processed: 6329  -  ('rec-1248-dup-0', 'rec-1248-org')
# Processed: 6330  -  ('rec-1248-dup-0', 'rec-1248-dup-2')
# Processed: 6331  -  ('rec-1248-dup-1', 'rec-1248-org')
# Processed: 6332  -  ('rec-1248-dup-1', 'rec-1248-dup-2')
# Processed: 6333  -  ('rec-1248-dup-1', 'rec-1248-dup-0')
# Processed: 6334  -  ('rec-1305-dup-1', 'rec-1305-org')
# Processed: 6335  -  ('rec-1305-dup-0', 'rec-1305-org')
# Processed: 6336  -  ('rec-1305-dup-0', 'rec-1305-dup-1')
# Processed: 6337  -  ('rec-590-org', 'rec-590-dup-0')
# Processed: 6338  -  ('rec-1102-org', 'rec-1102-dup-0')
# Processed: 6339  -  ('rec-1102-dup-1', 'rec-1102-dup-0')
# Processed: 6340  -  ('rec-1102-dup-1', 'rec-1102-org')
# Processed: 6341  -  ('rec-1503-dup-2', 'rec-1503-org')
# Processed: 6342  -  ('rec-1503-dup-1', 'rec-1503-org')
# Processed: 6343  -  ('rec-1503-dup-1', 'rec-1503-dup-2')
# Processed: 6344  -  ('rec-1503-dup-0', 'rec-1503-org')
# Processed: 6345  -  ('rec-1503-dup-0', 'rec-1503-dup-2')
# Processed: 6346  -  ('rec-1503-dup-0', 'rec-1503-dup-1')
# Processed: 6347  -  ('rec-616-org', 'rec-616-dup-0')
# Processed: 6348  -  ('rec-1844-org', 'rec-1844-dup-0')
# Processed: 6349  -  ('rec-150-org', 'rec-150-dup-0')
# Processed: 6350  -  ('rec-560-dup-1', 'rec-560-org')
# Processed: 6351  -  ('rec-560-dup-0', 'rec-560-org')
# Processed: 6352  -  ('rec-560-dup-0', 'rec-560-dup-1')
# Processed: 6353  -  ('rec-1168-dup-0', 'rec-1168-org')
# Processed: 6354  -  ('rec-789-org', 'rec-789-dup-0')
# Processed: 6355  -  ('rec-789-dup-1', 'rec-789-dup-0')
# Processed: 6356  -  ('rec-789-dup-1', 'rec-789-org')
# Processed: 6357  -  ('rec-881-org', 'rec-881-dup-1')
# Processed: 6358  -  ('rec-881-dup-0', 'rec-881-dup-1')
# Processed: 6359  -  ('rec-881-dup-0', 'rec-881-org')
# Processed: 6360  -  ('rec-62-org', 'rec-62-dup-0')
# Processed: 6361  -  ('rec-1779-dup-4', 'rec-1779-dup-3')
# Processed: 6362  -  ('rec-1779-dup-2', 'rec-1779-dup-3')
# Processed: 6363  -  ('rec-1779-dup-2', 'rec-1779-dup-4')
# Processed: 6364  -  ('rec-1779-dup-1', 'rec-1779-dup-3')
# Processed: 6365  -  ('rec-1779-dup-1', 'rec-1779-dup-4')
# Processed: 6366  -  ('rec-1779-dup-1', 'rec-1779-dup-2')
# Processed: 6367  -  ('rec-1779-org', 'rec-1779-dup-3')
# Processed: 6368  -  ('rec-1779-org', 'rec-1779-dup-4')
# Processed: 6369  -  ('rec-1779-org', 'rec-1779-dup-2')
# Processed: 6370  -  ('rec-1779-org', 'rec-1779-dup-1')
# Processed: 6371  -  ('rec-1779-dup-0', 'rec-1779-dup-3')
# Processed: 6372  -  ('rec-1779-dup-0', 'rec-1779-dup-4')
# Processed: 6373  -  ('rec-1779-dup-0', 'rec-1779-dup-2')
# Processed: 6374  -  ('rec-1779-dup-0', 'rec-1779-dup-1')
# Processed: 6375  -  ('rec-1779-dup-0', 'rec-1779-org')
# Processed: 6376  -  ('rec-330-org', 'rec-330-dup-0')
# Processed: 6377  -  ('rec-330-dup-1', 'rec-330-dup-0')
# Processed: 6378  -  ('rec-330-dup-1', 'rec-330-org')
# Processed: 6379  -  ('rec-330-dup-3', 'rec-330-dup-0')
# Processed: 6380  -  ('rec-330-dup-3', 'rec-330-org')
# Processed: 6381  -  ('rec-330-dup-3', 'rec-330-dup-1')
# Processed: 6382  -  ('rec-330-dup-2', 'rec-330-dup-0')
# Processed: 6383  -  ('rec-330-dup-2', 'rec-330-org')
# Processed: 6384  -  ('rec-330-dup-2', 'rec-330-dup-1')
# Processed: 6385  -  ('rec-330-dup-2', 'rec-330-dup-3')
# Processed: 6386  -  ('rec-1318-dup-1', 'rec-1318-dup-0')
# Processed: 6387  -  ('rec-1318-org', 'rec-1318-dup-0')
# Processed: 6388  -  ('rec-1318-org', 'rec-1318-dup-1')
# Processed: 6389  -  ('rec-1318-dup-2', 'rec-1318-dup-0')
# Processed: 6390  -  ('rec-1318-dup-2', 'rec-1318-dup-1')
# Processed: 6391  -  ('rec-1318-dup-2', 'rec-1318-org')
# Processed: 6392  -  ('rec-1381-dup-1', 'rec-1381-org')
# Processed: 6393  -  ('rec-1381-dup-0', 'rec-1381-org')
# Processed: 6394  -  ('rec-1381-dup-0', 'rec-1381-dup-1')
# Processed: 6395  -  ('rec-721-dup-0', 'rec-721-dup-3')
# Processed: 6396  -  ('rec-721-dup-1', 'rec-721-dup-3')
# Processed: 6397  -  ('rec-721-dup-1', 'rec-721-dup-0')
# Processed: 6398  -  ('rec-721-dup-2', 'rec-721-dup-3')
# Processed: 6399  -  ('rec-721-dup-2', 'rec-721-dup-0')
# Processed: 6400  -  ('rec-721-dup-2', 'rec-721-dup-1')
# Processed: 6401  -  ('rec-721-org', 'rec-721-dup-3')
# Processed: 6402  -  ('rec-721-org', 'rec-721-dup-0')
# Processed: 6403  -  ('rec-721-org', 'rec-721-dup-1')
# Processed: 6404  -  ('rec-721-org', 'rec-721-dup-2')
# Processed: 6405  -  ('rec-1250-dup-0', 'rec-1250-org')
# Processed: 6406  -  ('rec-1250-dup-1', 'rec-1250-org')
# Processed: 6407  -  ('rec-1250-dup-1', 'rec-1250-dup-0')
# Processed: 6408  -  ('rec-800-org', 'rec-800-dup-0')
# Processed: 6409  -  ('rec-1796-dup-0', 'rec-1796-org')
# Processed: 6410  -  ('rec-1108-org', 'rec-1108-dup-0')
# Processed: 6411  -  ('rec-886-dup-1', 'rec-886-org')
# Processed: 6412  -  ('rec-886-dup-0', 'rec-886-org')
# Processed: 6413  -  ('rec-886-dup-0', 'rec-886-dup-1')
# Processed: 6414  -  ('rec-1974-dup-0', 'rec-1974-org')
# Processed: 6415  -  ('rec-1163-dup-0', 'rec-1163-org')
# Processed: 6416  -  ('rec-1051-org', 'rec-1051-dup-0')
# Processed: 6417  -  ('rec-1377-dup-1', 'rec-1377-dup-0')
# Processed: 6418  -  ('rec-1377-org', 'rec-1377-dup-0')
# Processed: 6419  -  ('rec-1377-org', 'rec-1377-dup-1')
# Processed: 6420  -  ('rec-822-dup-0', 'rec-822-org')
# Processed: 6421  -  ('rec-22-dup-0', 'rec-22-org')
# Processed: 6422  -  ('rec-664-dup-0', 'rec-664-org')
# Processed: 6423  -  ('rec-664-dup-1', 'rec-664-org')
# Processed: 6424  -  ('rec-664-dup-1', 'rec-664-dup-0')
# Processed: 6425  -  ('rec-349-dup-0', 'rec-349-org')
# Processed: 6426  -  ('rec-135-dup-0', 'rec-135-dup-1')
# Processed: 6427  -  ('rec-135-org', 'rec-135-dup-1')
# Processed: 6428  -  ('rec-135-org', 'rec-135-dup-0')
# Processed: 6429  -  ('rec-1573-org', 'rec-1573-dup-0')
# Processed: 6430  -  ('rec-781-dup-0', 'rec-781-org')
# Processed: 6431  -  ('rec-476-dup-0', 'rec-476-dup-1')
# Processed: 6432  -  ('rec-476-org', 'rec-476-dup-1')
# Processed: 6433  -  ('rec-476-org', 'rec-476-dup-0')
# Processed: 6434  -  ('rec-476-dup-2', 'rec-476-dup-1')
# Processed: 6435  -  ('rec-476-dup-2', 'rec-476-dup-0')
# Processed: 6436  -  ('rec-476-dup-2', 'rec-476-org')
# Processed: 6437  -  ('rec-387-org', 'rec-387-dup-0')
# Processed: 6438  -  ('rec-1574-org', 'rec-1574-dup-0')
# Processed: 6439  -  ('rec-1574-dup-1', 'rec-1574-dup-0')
# Processed: 6440  -  ('rec-1574-dup-1', 'rec-1574-org')
# Processed: 6441  -  ('rec-1119-org', 'rec-1119-dup-0')
# Processed: 6442  -  ('rec-1640-dup-0', 'rec-1640-org')
# Processed: 6443  -  ('rec-174-dup-0', 'rec-174-org')
# Processed: 6444  -  ('rec-1922-dup-1', 'rec-1922-dup-0')
# Processed: 6445  -  ('rec-1922-org', 'rec-1922-dup-0')
# Processed: 6446  -  ('rec-1922-org', 'rec-1922-dup-1')
# Processed: 6447  -  ('rec-119-org', 'rec-119-dup-0')
# Processed: 6448  -  ('rec-1902-org', 'rec-1902-dup-1')
# Processed: 6449  -  ('rec-1902-dup-0', 'rec-1902-dup-1')
# Processed: 6450  -  ('rec-1902-dup-0', 'rec-1902-org')
# Processed: 6451  -  ('rec-1605-dup-0', 'rec-1605-org')
# Processed: 6452  -  ('rec-1605-dup-1', 'rec-1605-org')
# Processed: 6453  -  ('rec-1605-dup-1', 'rec-1605-dup-0')
# Processed: 6454  -  ('rec-16-dup-0', 'rec-16-org')
# Processed: 6455  -  ('rec-95-org', 'rec-95-dup-0')
# Processed: 6456  -  ('rec-117-org', 'rec-117-dup-0')
# Processed: 6457  -  ('rec-117-dup-1', 'rec-117-dup-0')
# Processed: 6458  -  ('rec-117-dup-1', 'rec-117-org')
# Processed: 6459  -  ('rec-1625-dup-1', 'rec-1625-dup-2')
# Processed: 6460  -  ('rec-1625-org', 'rec-1625-dup-2')
# Processed: 6461  -  ('rec-1625-org', 'rec-1625-dup-1')
# Processed: 6462  -  ('rec-1625-dup-0', 'rec-1625-dup-2')
# Processed: 6463  -  ('rec-1625-dup-0', 'rec-1625-dup-1')
# Processed: 6464  -  ('rec-1625-dup-0', 'rec-1625-org')
# Processed: 6465  -  ('rec-1906-dup-0', 'rec-1906-org')
# Processed: 6466  -  ('rec-621-dup-0', 'rec-621-org')
# Processed: 6467  -  ('rec-1378-org', 'rec-1378-dup-0')
# Processed: 6468  -  ('rec-1344-org', 'rec-1344-dup-0')
# Processed: 6469  -  ('rec-1344-dup-1', 'rec-1344-dup-0')
# Processed: 6470  -  ('rec-1344-dup-1', 'rec-1344-org')
# Processed: 6471  -  ('rec-1608-org', 'rec-1608-dup-0')
# Processed: 6472  -  ('rec-1636-org', 'rec-1636-dup-0')
# Processed: 6473  -  ('rec-357-org', 'rec-357-dup-0')
# Processed: 6474  -  ('rec-669-dup-1', 'rec-669-dup-2')
# Processed: 6475  -  ('rec-669-dup-0', 'rec-669-dup-2')
# Processed: 6476  -  ('rec-669-dup-0', 'rec-669-dup-1')
# Processed: 6477  -  ('rec-669-org', 'rec-669-dup-2')
# Processed: 6478  -  ('rec-669-org', 'rec-669-dup-1')
# Processed: 6479  -  ('rec-669-org', 'rec-669-dup-0')
# Processed: 6480  -  ('rec-1293-org', 'rec-1293-dup-1')
# Processed: 6481  -  ('rec-1293-dup-0', 'rec-1293-dup-1')
# Processed: 6482  -  ('rec-1293-dup-0', 'rec-1293-org')
# Processed: 6483  -  ('rec-1404-dup-0', 'rec-1404-org')
# Processed: 6484  -  ('rec-1934-dup-0', 'rec-1934-org')
# Processed: 6485  -  ('rec-1982-dup-0', 'rec-1982-org')
# Processed: 6486  -  ('rec-902-dup-0', 'rec-902-org')
# Processed: 6487  -  ('rec-69-org', 'rec-69-dup-0')
# Processed: 6488  -  ('rec-1601-dup-0', 'rec-1601-org')
# Processed: 6489  -  ('rec-1321-org', 'rec-1321-dup-0')
# Processed: 6490  -  ('rec-1656-dup-0', 'rec-1656-org')
# Processed: 6491  -  ('rec-1240-dup-0', 'rec-1240-org')
# Processed: 6492  -  ('rec-1104-dup-0', 'rec-1104-org')
# Processed: 6493  -  ('rec-1104-dup-1', 'rec-1104-org')
# Processed: 6494  -  ('rec-1104-dup-1', 'rec-1104-dup-0')
# Processed: 6495  -  ('rec-746-org', 'rec-746-dup-0')
# Processed: 6496  -  ('rec-399-dup-0', 'rec-399-org')
# Processed: 6497  -  ('rec-1923-org', 'rec-1923-dup-0')
# Processed: 6498  -  ('rec-1261-dup-2', 'rec-1261-org')
# Processed: 6499  -  ('rec-1261-dup-1', 'rec-1261-org')
# Processed: 6500  -  ('rec-1261-dup-1', 'rec-1261-dup-2')
# Processed: 6501  -  ('rec-1261-dup-0', 'rec-1261-org')
# Processed: 6502  -  ('rec-1261-dup-0', 'rec-1261-dup-2')
# Processed: 6503  -  ('rec-1261-dup-0', 'rec-1261-dup-1')
# Processed: 6504  -  ('rec-1624-dup-1', 'rec-1624-org')
# Processed: 6505  -  ('rec-1624-dup-2', 'rec-1624-org')
# Processed: 6506  -  ('rec-1624-dup-2', 'rec-1624-dup-1')
# Processed: 6507  -  ('rec-1624-dup-0', 'rec-1624-org')
# Processed: 6508  -  ('rec-1624-dup-0', 'rec-1624-dup-1')
# Processed: 6509  -  ('rec-1624-dup-0', 'rec-1624-dup-2')
# Processed: 6510  -  ('rec-1422-dup-0', 'rec-1422-org')
# Processed: 6511  -  ('rec-1095-dup-0', 'rec-1095-org')
# Processed: 6512  -  ('rec-68-dup-1', 'rec-68-org')
# Processed: 6513  -  ('rec-68-dup-2', 'rec-68-org')
# Processed: 6514  -  ('rec-68-dup-2', 'rec-68-dup-1')
# Processed: 6515  -  ('rec-68-dup-0', 'rec-68-org')
# Processed: 6516  -  ('rec-68-dup-0', 'rec-68-dup-1')
# Processed: 6517  -  ('rec-68-dup-0', 'rec-68-dup-2')
# Processed: 6518  -  ('rec-903-org', 'rec-903-dup-0')
# Processed: 6519  -  ('rec-613-org', 'rec-613-dup-0')
# Processed: 6520  -  ('rec-791-dup-0', 'rec-791-org')
# Processed: 6521  -  ('rec-235-org', 'rec-235-dup-0')
# Processed: 6522  -  ('rec-626-dup-1', 'rec-626-org')
# Processed: 6523  -  ('rec-626-dup-0', 'rec-626-org')
# Processed: 6524  -  ('rec-626-dup-0', 'rec-626-dup-1')
# Processed: 6525  -  ('rec-695-org', 'rec-695-dup-0')
# Processed: 6526  -  ('rec-1291-org', 'rec-1291-dup-0')
# Processed: 6527  -  ('rec-94-dup-0', 'rec-94-org')
# Processed: 6528  -  ('rec-1327-dup-0', 'rec-1327-org')
# Processed: 6529  -  ('rec-1529-dup-0', 'rec-1529-org')
# Processed: 6530  -  ('rec-1846-dup-0', 'rec-1846-org')
# Processed: 6531  -  ('rec-163-org', 'rec-163-dup-0')
# Processed: 6532  -  ('rec-1282-dup-0', 'rec-1282-org')
# Processed: 6533  -  ('rec-521-org', 'rec-521-dup-0')
# Processed: 6534  -  ('rec-939-dup-0', 'rec-939-org')
# Processed: 6535  -  ('rec-1956-dup-0', 'rec-1956-org')
# Processed: 6536  -  ('rec-214-org', 'rec-214-dup-0')
# Processed: 6537  -  ('rec-1435-dup-0', 'rec-1435-org')

# %%
#df.to_csv("febrl3_UNSW.csv", index=True)

df.to_csv(outputfile, index=True)
#df.to_csv("febrl4_UNSW.csv", index=True)
